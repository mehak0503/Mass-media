# %%
# Importing the required libraries.
import numpy as np
import pandas as pd
import pickle, zlib
from random import sample
import scipy.cluster.hierarchy as sch
from gensim.models.doc2vec import Doc2Vec
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
from gensim import corpora, models

# Show graph
# %matplotlib inline
import matplotlib.pyplot as plt
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
import gensim.corpora as corpora
# Out:
# [nltk_data] Downloading package wordnet to /home/ubuntu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# For TF-IDF keywords and scores.
def display_scores(vectorizer, tfidf_result):
    scores = zip(vectorizer.get_feature_names(),np.asarray(tfidf_result.sum(axis=0)).ravel())
    sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)
    tf_idf_words, tf_idf_scores = [], []
    useless_words = set(['offici','said','govern','near','irregular','special','say','ad','minist','chief','clash','bodi','local','time','work','vigil','mla','region', 'get','start','member','mahatma','congress','state','gram','depart', 'rs', 'crore', 'also', 'card', 'district', 'tuesday', 'offic', 'year', 'meet', 'day', 'would', 'peopl', 'nation', 'lakh', 'plan', 'union', 'alleg', 'provid', 'two', 'km', 'taken', 'guarante', 'take', 'complet', 'report', 'case', 'found', 'per', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'monday', 'tuesday', 'wednesday', 'thrusday', 'friday', 'saturday', 'sunday', 'issu', 'ask', 'level', 'order', 'parti', 'director', 'releas', 'bjp', 'sourc', 'cm', 'injur', 'mr', 'ramesh', 'visit', 'act', 'famili', 'secretari', 'first', 'last', 'includ', 'probe', 'direct', 'month'])
    for item in sorted_scores:
        if item[0] not in useless_words:
            tf_idf_words.append(item[0])
            tf_idf_scores.append(np.round(item[1],2))
    return tf_idf_words,tf_idf_scores

# Resolve article_ids to their corresponding titles and tf_idf_keywords.
def resolve_articles(ids, dataset):
    data = {}
    for i in dataset:
        if i[0] not in data:
            data[i[0]] = [i[1],i[3]]
    titles = []
    resolved_text = []
    for i in ids:
        titles.append(data[i][0])
        resolved_text.append(data[i][1])
    for i in range(len(resolved_text)):
        temp = ''
        for j in resolved_text[i]:
            temp+=(j+' ')
        resolved_text[i] = temp      
    vectorizer = TfidfVectorizer()
    tfidf_result = vectorizer.fit_transform(resolved_text)
    result = display_scores(vectorizer, tfidf_result)
    return titles, result[0], result[1]

# %%
import numpy as np

def intersection(lst1, lst2): 
    return list(lst1 & lst2) 

def find_unique(articles):
    n = len(articles)
    l = [[0]*n]*n
    matched_count = np.array(l,dtype=np.float32)
    ind = range(n)
    art_split = [set(i.split(' ')) for i in articles]
    art_len = [len(i.split(' ')) for i in articles]
    for i, j in zip(ind, ind[1:]):
        avg = (art_len[i] + art_len[j])/2
        cnt = len(intersection(art_split[i],art_split[j]))/avg
        matched_count[i,j] = cnt
        matched_count[j,i] = cnt
    aggr = [sum(i) for i in matched_count]
    indx = np.argsort(aggr)
    return indx

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
def compute_coherence_values(dictionary, corpus, texts, limit=20, start=5, step=5):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model=LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
def plot_values(coherence_values,start=5,limit=20,step=5):
  x = range(start, limit, step)
  plt.plot(x, coherence_values)
  plt.xlabel("Num Topics")
  plt.ylabel("Coherence score")
  plt.legend(("coherence_values"), loc='best')
  plt.show()

# %%
def lda_model(docs,topics=10,start=10,limit=20,step=5,use_coherence=0):
  id2word = corpora.Dictionary(docs)# Create Corpus
  texts = docs# Term Document Frequency
  corpus = [id2word.doc2bow(text) for text in texts]# View
  if use_coherence:
    model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts)
    plot_values(coherence_values)
    lda = model_list[coherence_values.index(max(coherence_values))]
    fin_top = coherence_values.index(max(coherence_values))
  else:
    lda = LdaModel(corpus=corpus, id2word=id2word, num_topics=topics)
  #lda_model.save('/content/drive/My Drive/MTP/MTP_Final/model/lda_nagri_1')
  for i in lda.show_topics():
    print(i)
  return lda,corpus#,fin_top

# %%
def top_docs(index,lda_model,corpus,filtered_docs,topics=10,top_num=30):
  topic_dict = {i: [] for i in range(topics)}  # Assuming you have 20 topics. 
  #Loop over all the documents to group the probability of each topic
  num_docs=len(filtered_docs)
  for docID in range(num_docs):
      topic_vector = lda_model[corpus[docID]]
      #print(docID,topic_vector)
      for topicID, prob in topic_vector:
          topic_dict[topicID].append((docID, prob))
  res_index = []
  #Then, you can sort the dictionary to find the top 20 documents:
  docs = []
  for topicID, probs in topic_dict.items():
      doc_probs = sorted(probs, key = lambda x: x[1], reverse = True)
      #print(doc_probs)
      docs_top = [dp[0] for dp in doc_probs[:top_num]]
      ind = [index[dp[0]] for dp in doc_probs[:top_num]]  
      res_index.append(ind)
      docs.append(docs_top)
  #print(docs)
  final_docs=[]
  final_ind = []
  for i in docs:
    lst = []
    for j in i:
      #print(len(lst))
      final_docs.append(filtered_docs[j])
  #print(len(final_docs))
  for i in res_index:
    for j in i:
      final_ind.append(j)
  #print(final_ind)
  return final_docs,final_ind

# %%
import pandas as pd
datasets = ['dataset_agriculture', 'dataset_development', 'dataset_environment', 'dataset_industrialization', 'dataset_lifestyle']
model_names = ['model_agriculture', 'model_development', 'model_environment', 'model_industrialization', 'model_lifestyle']
final_res_all = []
for dataset, model in zip(datasets,model_names):
    dataset_name = dataset
    # Printing the collection name.
    collection_name = dataset[8:]
    print('\nCollection:',collection_name.capitalize())

    # Loading the dataset and the model from the drive.
    file = open('Datasets/'+dataset, 'rb')
    dataset = pickle.loads(zlib.decompress(pickle.load(file)))
    file.close()
    
    # Collecting the article_ids, and corresponding article_vectors for each class.
    temp_ids = [set() for _ in range(9)]
    temp_vectors = [[] for _ in range(9)]
    temp_datasets = [[] for _ in range(9)]
    for i in dataset:
        if i[6]=='Unemp' and i[-1]=='Slow':
            if i[0] not in temp_ids[0]:
                temp_ids[0].add(i[0])
                temp_vectors[0].append(i[2].split(' '))
        if i[6]=='Unemp' and i[-1]=='Average':
            if i[0] not in temp_ids[1]:
                temp_ids[1].add(i[0])
                temp_vectors[1].append(i[2].split(' '))
        if i[6]=='Unemp' and i[-1]=='Fast':
            if i[0] not in temp_ids[2]:
                temp_ids[2].add(i[0])
                temp_vectors[2].append(i[2].split(' '))
        if i[6]=='Agri' and i[-1]=='Slow':
            if i[0] not in temp_ids[3]:
                temp_ids[3].add(i[0])
                temp_vectors[3].append(i[2].split(' '))
        if i[6]=='Agri' and i[-1]=='Average':
            if i[0] not in temp_ids[4]:
                temp_ids[4].add(i[0])
                temp_vectors[4].append(i[2].split(' '))
        if i[6]=='Agri' and i[-1]=='Fast':
            if i[0] not in temp_ids[5]:
                temp_ids[5].add(i[0])
                temp_vectors[5].append(i[2].split(' '))
        if i[6]=='Non Agri' and i[-1]=='Slow':
            if i[0] not in temp_ids[6]:
                temp_ids[6].add(i[0])
                temp_vectors[6].append(i[2].split(' '))
        if i[6]=='Non Agri' and i[-1]=='Average':
            if i[0] not in temp_ids[7]:
                temp_ids[7].add(i[0])
                temp_vectors[7].append(i[2].split(' '))
        if i[6]=='Non Agri' and i[-1]=='Fast':
            if i[0] not in temp_ids[8]:
                temp_ids[8].add(i[0])
                temp_vectors[8].append(i[2].split(' '))
    # Finding the top titles and keywords for each class.
    names = ['unemp_avg','unemp_slow','unemp_fast','agri_avg','agri_slow','agri_fast','non_agri_avg','non_agri_slow','non_agri_fast']
    df = pd.DataFrame()
    df_ids = pd.DataFrame()
    for i in range(9):
        print(names[i].capitalize())
        result = lda_model(temp_vectors[i])
        final_res = top_docs(list(temp_ids[i]),result[0],result[1],temp_vectors[i])#,(result[2]+1)*5)
        aresult = resolve_articles(final_res[1],dataset)
        for j in aresult[0][:10]:
            print(j)
        df[names[i]+'_title'] = aresult[0][:10]
        df[names[i]+'_id']= final_res[1][:10]
        if len(final_res[1])<100:
            df_ids[names[i]+'_id'] = final_res[1][:100] + ['0' for _ in range(100-len(final_res[1]))]
        else:
            df_ids[names[i]+'_id'] = final_res[1][:100]
    
    df.to_excel('LDA/'+collection_name+'.xlsx',index=False)
    df_ids.to_excel('LDA/'+collection_name+'_ids.xlsx',index=False)
# Out:
# Collection: Agriculture
# Unemp_slow
# (0, '0.028*"the" + 0.022*"of" + 0.014*"and" + 0.012*"to" + 0.011*"a" + 0.011*"in" + 0.006*"for" + 0.005*"is" + 0.005*"was" + 0.004*"that"')
# (1, '0.034*"the" + 0.019*"of" + 0.016*"in" + 0.015*"to" + 0.014*"and" + 0.006*"that" + 0.006*"a" + 0.005*"for" + 0.004*"on" + 0.004*"is"')
# (2, '0.026*"the" + 0.018*"of" + 0.015*"in" + 0.014*"and" + 0.011*"to" + 0.008*"for" + 0.008*"a" + 0.004*"on" + 0.004*"at" + 0.004*"was"')
# (3, '0.069*"the" + 0.026*"to" + 0.023*"of" + 0.021*"and" + 0.019*"in" + 0.018*"a" + 0.015*"for" + 0.011*"on" + 0.010*"that" + 0.008*"water"')
# (4, '0.063*"the" + 0.042*"of" + 0.033*"in" + 0.029*"to" + 0.026*"and" + 0.013*"a" + 0.011*"is" + 0.010*"for" + 0.008*"has" + 0.008*"on"')
# (5, '0.025*"and" + 0.008*"of" + 0.007*"the" + 0.006*"0" + 0.006*"in" + 0.005*"each," + 0.004*"over" + 0.004*"at" + 0.004*"25" + 0.004*"places"')
# (6, '0.047*"the" + 0.036*"of" + 0.024*"and" + 0.023*"in" + 0.019*"to" + 0.011*"for" + 0.011*"a" + 0.009*"farmers" + 0.009*"on" + 0.007*"is"')
# (7, '0.016*"the" + 0.012*"of" + 0.011*"in" + 0.009*"and" + 0.007*"a" + 0.007*"to" + 0.005*"for" + 0.004*"on" + 0.003*"from" + 0.003*"had"')
# (8, '0.066*"the" + 0.030*"of" + 0.029*"and" + 0.027*"to" + 0.027*"in" + 0.021*"a" + 0.012*"on" + 0.009*"was" + 0.009*"for" + 0.008*"from"')
# (9, '0.030*"the" + 0.020*"of" + 0.016*"in" + 0.014*"to" + 0.013*"and" + 0.008*"a" + 0.007*"for" + 0.005*"is" + 0.005*"on" + 0.005*"with"')
# 195
# A show of khadi and hand weaves
# Rahul Gandhi’s padyatra in Odisha to bring focus on farmers’ issue
# Power grid sub-station ransacked after nine-year-old boy is electrocuted
# Bank officials threatening me: Mallya’s ‘guarantor’
# Lightning strikes kill 10 in state
# Sindhudurg airport may be completed by June
# Govt aid
# Land acquired for four-lane, says MP
# 50-year-old's head severed as truck hits motorcycle
# Farmers warn of indefinite stir in Rajasthan from June 15
# Unemp_stag
# (0, '0.056*"the" + 0.042*"of" + 0.028*"in" + 0.026*"and" + 0.025*"to" + 0.022*"a" + 0.015*"is" + 0.008*"that" + 0.008*"for" + 0.008*"from"')
# (1, '0.035*"the" + 0.030*"and" + 0.024*"in" + 0.023*"of" + 0.022*"to" + 0.013*"on" + 0.012*"a" + 0.008*"were" + 0.007*"been" + 0.007*"was"')
# (2, '0.007*"the" + 0.006*"to" + 0.005*"of" + 0.004*"and" + 0.003*"in" + 0.003*"a" + 0.002*"on" + 0.002*"from" + 0.001*"for" + 0.001*"are"')
# (3, '0.021*"the" + 0.011*"of" + 0.009*"to" + 0.008*"in" + 0.007*"and" + 0.006*"a" + 0.006*"for" + 0.005*"on" + 0.004*"is" + 0.003*"was"')
# (4, '0.056*"the" + 0.035*"of" + 0.029*"in" + 0.027*"and" + 0.024*"to" + 0.016*"a" + 0.009*"on" + 0.009*"is" + 0.008*"The" + 0.007*"for"')
# (5, '0.017*"the" + 0.012*"to" + 0.008*"in" + 0.008*"and" + 0.008*"of" + 0.005*"a" + 0.003*"that" + 0.003*"on" + 0.003*"is" + 0.003*"for"')
# (6, '0.068*"the" + 0.035*"in" + 0.029*"of" + 0.024*"to" + 0.024*"and" + 0.017*"a" + 0.015*"on" + 0.015*"was" + 0.009*"for" + 0.008*"from"')
# (7, '0.072*"the" + 0.035*"of" + 0.031*"to" + 0.026*"and" + 0.022*"in" + 0.014*"a" + 0.014*"for" + 0.011*"on" + 0.007*"that" + 0.007*"be"')
# (8, '0.038*"the" + 0.015*"to" + 0.013*"of" + 0.011*"a" + 0.009*"his" + 0.009*"and" + 0.008*"in" + 0.007*"RJD" + 0.006*"Lalu" + 0.006*"on"')
# (9, '0.022*"and" + 0.009*"0" + 0.006*"each," + 0.005*"in" + 0.005*"25" + 0.005*"of" + 0.004*"at" + 0.004*"over" + 0.004*"places" + 0.004*"24"')
# 226
# Double trouble for veggie basket
# ‘Agriculture production jumps in country’
# CPM rally
# Centre stalls Bt maize trial at CM’s behest
# With high hopes
# Gang-rape, now in Patna rural
# Bodies of three youths found in canal
# 'Acche din' for Bihar: PM Modi announces Rs 1.25 lakh crore package
# Rail land corporate use heat  on Centre
# ‘Speedstar’ hones his athletic skills down under
# Unemp_fast
# (0, '0.069*"the" + 0.036*"of" + 0.029*"and" + 0.027*"to" + 0.027*"in" + 0.017*"a" + 0.011*"for" + 0.010*"on" + 0.009*"is" + 0.008*"that"')
# (1, '0.044*"the" + 0.022*"and" + 0.020*"of" + 0.014*"to" + 0.012*"in" + 0.011*"0" + 0.010*"a" + 0.008*"on" + 0.007*"for" + 0.006*"was"')
# (2, '0.034*"the" + 0.033*"of" + 0.032*"in" + 0.021*"and" + 0.015*"to" + 0.010*"a" + 0.009*"on" + 0.007*"was" + 0.006*"is" + 0.005*"for"')
# (3, '0.013*"the" + 0.009*"in" + 0.008*"and" + 0.007*"to" + 0.007*"of" + 0.005*"a" + 0.003*"has" + 0.003*"on" + 0.002*"was" + 0.002*"for"')
# (4, '0.034*"the" + 0.025*"and" + 0.023*"of" + 0.023*"in" + 0.015*"to" + 0.014*"a" + 0.008*"is" + 0.008*"for" + 0.007*"on" + 0.006*"that"')
# (5, '0.041*"the" + 0.022*"of" + 0.020*"in" + 0.020*"to" + 0.019*"and" + 0.015*"a" + 0.007*"from" + 0.007*"for" + 0.005*"have" + 0.005*"at"')
# (6, '0.034*"in" + 0.029*"the" + 0.024*"to" + 0.023*"and" + 0.020*"of" + 0.010*"a" + 0.009*"is" + 0.009*"has" + 0.008*"was" + 0.007*"on"')
# (7, '0.053*"the" + 0.029*"in" + 0.026*"to" + 0.025*"of" + 0.016*"a" + 0.014*"and" + 0.011*"for" + 0.009*"is" + 0.008*"that" + 0.007*"on"')
# (8, '0.035*"the" + 0.032*"to" + 0.032*"of" + 0.023*"in" + 0.017*"a" + 0.017*"and" + 0.010*"for" + 0.010*"was" + 0.009*"that" + 0.008*"on"')
# (9, '0.023*"the" + 0.018*"and" + 0.014*"in" + 0.012*"to" + 0.010*"of" + 0.009*"for" + 0.008*"a" + 0.005*"from" + 0.004*"is" + 0.004*"The"')
# 251
# Lightning kills two brothers near Kalol
# Three farmers died of cardiac arrest after seeing their crops destroyed in untimely rains
# Thanjavur farmers stick to demand for compensation
# Property licensing to go online in Haryana
# ‘Restore subsidy for all paddy seeds’
# Cong dares BJP for public debate on coal controversy
# Indo-German project to conserve traditional rice landraces
# Jumbo menace forces Jajpur villagers to stay atop trees
# Four Gujaratis get Padma awards
# Urea shortage continues to rile farmers
# Agri_slow
# (0, '0.045*"the" + 0.039*"in" + 0.026*"to" + 0.026*"of" + 0.024*"and" + 0.020*"a" + 0.017*"on" + 0.015*"was" + 0.012*"at" + 0.011*"his"')
# (1, '0.050*"the" + 0.037*"in" + 0.034*"of" + 0.034*"and" + 0.021*"to" + 0.011*"on" + 0.009*"has" + 0.009*"a" + 0.009*"been" + 0.008*"have"')
# (2, '0.003*"the" + 0.002*"of" + 0.001*"in" + 0.001*"and" + 0.001*"to" + 0.001*"is" + 0.001*"a" + 0.001*"was" + 0.000*"on" + 0.000*"from"')
# (3, '0.018*"in" + 0.012*"Chikmagalur" + 0.010*"of" + 0.007*"rain" + 0.007*"Mudigere" + 0.006*"recorded" + 0.006*"and" + 0.006*"rainfall" + 0.006*"taluk" + 0.005*"received"')
# (4, '0.005*"the" + 0.003*"to" + 0.003*"in" + 0.003*"of" + 0.003*"and" + 0.001*"a" + 0.001*"that" + 0.001*"is" + 0.001*"from" + 0.001*"have"')
# (5, '0.003*"the" + 0.002*"to" + 0.001*"in" + 0.001*"of" + 0.001*"and" + 0.001*"a" + 0.001*"for" + 0.001*"that" + 0.000*"from" + 0.000*"was"')
# (6, '0.011*"the" + 0.007*"in" + 0.007*"of" + 0.006*"to" + 0.005*"and" + 0.002*"for" + 0.002*"on" + 0.002*"a" + 0.002*"is" + 0.002*"has"')
# (7, '0.045*"the" + 0.031*"and" + 0.017*"her" + 0.017*"a" + 0.016*"of" + 0.015*"Congress" + 0.014*"to" + 0.013*"in" + 0.008*"police" + 0.008*"she"')
# (8, '0.004*"the" + 0.002*"to" + 0.002*"and" + 0.002*"in" + 0.002*"of" + 0.001*"on" + 0.001*"a" + 0.001*"was" + 0.001*"for" + 0.001*"at"')
# (9, '0.069*"the" + 0.038*"of" + 0.031*"to" + 0.028*"in" + 0.025*"and" + 0.016*"a" + 0.013*"for" + 0.010*"is" + 0.010*"on" + 0.009*"that"')
# 157
# Heavy rain wreaks havoc in Karnataka
# KCR all praise for Gangadevipally
# Verdict in 61-yr-old land case today
# Rajsamand Lake brimming with water for first time
# Twin strikes paralyse Imphal
# Farmers take out procession  stage dharna in Chitradurga
# Hailstorm damages rabi crops
# HC shocked by locations of liquor outlets
# Chief Minister inspects Godavari near Medigadda
# Passport centre plea
# Agri_stag
# (0, '0.028*"the" + 0.012*"of" + 0.009*"to" + 0.009*"and" + 0.008*"in" + 0.006*"a" + 0.005*"for" + 0.003*"on" + 0.003*"is" + 0.003*"that"')
# (1, '0.067*"the" + 0.032*"of" + 0.030*"to" + 0.020*"in" + 0.018*"and" + 0.013*"for" + 0.010*"a" + 0.010*"water" + 0.008*"at" + 0.008*"on"')
# (2, '0.069*"the" + 0.039*"of" + 0.032*"to" + 0.026*"and" + 0.023*"in" + 0.013*"on" + 0.013*"a" + 0.012*"for" + 0.009*"farmers" + 0.009*"that"')
# (3, '0.011*"the" + 0.007*"in" + 0.005*"to" + 0.004*"and" + 0.004*"of" + 0.002*"a" + 0.002*"for" + 0.002*"is" + 0.001*"has" + 0.001*"was"')
# (4, '0.010*"the" + 0.008*"of" + 0.006*"and" + 0.005*"in" + 0.004*"to" + 0.003*"for" + 0.003*"a" + 0.002*"was" + 0.002*"on" + 0.002*"is"')
# (5, '0.061*"the" + 0.032*"to" + 0.029*"of" + 0.026*"and" + 0.024*"in" + 0.024*"a" + 0.015*"is" + 0.010*"for" + 0.009*"are" + 0.008*"from"')
# (6, '0.065*"the" + 0.041*"of" + 0.036*"in" + 0.030*"and" + 0.024*"to" + 0.011*"a" + 0.010*"on" + 0.008*"was" + 0.008*"for" + 0.007*"is"')
# (7, '0.061*"the" + 0.032*"of" + 0.028*"in" + 0.026*"to" + 0.024*"and" + 0.021*"a" + 0.011*"on" + 0.011*"for" + 0.010*"was" + 0.010*"that"')
# (8, '0.073*"the" + 0.030*"in" + 0.029*"to" + 0.029*"and" + 0.026*"of" + 0.014*"for" + 0.012*"a" + 0.010*"on" + 0.009*"will" + 0.008*"is"')
# (9, '0.012*"the" + 0.008*"in" + 0.007*"of" + 0.005*"and" + 0.005*"to" + 0.005*"a" + 0.003*"is" + 0.003*"for" + 0.003*"that" + 0.002*"are"')
# 225
# MPHRC comes to the rescue of commoners
# Expert blames education system for farm crisis
# Search on to find dead lion's nails
# Sharp rise in prices of small onions
# Time to catch a ‘power’ nap
# Monsoon still inactive despite rain
# Protective measure
# Winter’s last lap gets longer
# 'Stop water supply from N'sagar to Krishna delta'
# No house, no car for Koneru!
# Agri_fast
# (0, '0.024*"the" + 0.017*"in" + 0.015*"to" + 0.015*"and" + 0.014*"of" + 0.007*"a" + 0.007*"is" + 0.005*"was" + 0.005*"are" + 0.004*"for"')
# (1, '0.065*"the" + 0.034*"to" + 0.034*"of" + 0.024*"and" + 0.022*"in" + 0.014*"a" + 0.012*"for" + 0.010*"is" + 0.008*"that" + 0.008*"on"')
# (2, '0.037*"the" + 0.015*"a" + 0.013*"to" + 0.013*"and" + 0.013*"of" + 0.013*"in" + 0.007*"for" + 0.006*"is" + 0.006*"was" + 0.005*"on"')
# (3, '0.064*"the" + 0.035*"in" + 0.034*"of" + 0.030*"and" + 0.023*"to" + 0.017*"a" + 0.011*"on" + 0.008*"is" + 0.008*"from" + 0.007*"for"')
# (4, '0.071*"the" + 0.035*"of" + 0.023*"in" + 0.019*"and" + 0.017*"a" + 0.016*"to" + 0.014*"for" + 0.011*"has" + 0.009*"that" + 0.009*"on"')
# (5, '0.004*"and" + 0.004*"the" + 0.003*"of" + 0.003*"in" + 0.002*"to" + 0.002*"a" + 0.002*"for" + 0.001*"is" + 0.001*"that" + 0.001*"have"')
# (6, '0.047*"the" + 0.030*"of" + 0.028*"and" + 0.026*"in" + 0.019*"to" + 0.010*"a" + 0.010*"for" + 0.010*"on" + 0.009*"rainfall" + 0.008*"was"')
# (7, '0.051*"the" + 0.026*"in" + 0.023*"and" + 0.020*"to" + 0.019*"a" + 0.016*"of" + 0.009*"for" + 0.009*"is" + 0.008*"was" + 0.008*"that"')
# (8, '0.052*"the" + 0.029*"to" + 0.026*"of" + 0.021*"in" + 0.020*"water" + 0.017*"and" + 0.010*"for" + 0.009*"a" + 0.009*"that" + 0.008*"is"')
# (9, '0.055*"the" + 0.034*"of" + 0.032*"to" + 0.024*"in" + 0.020*"and" + 0.018*"a" + 0.016*"is" + 0.010*"for" + 0.008*"on" + 0.008*"has"')
# 216
# Hill highway nearing completion
# Bikaner’s bhujia empire: How Agarwal family runs Rs 5,000 crore business covering 500 products
# Farmers resurrect tank
# Another suicide bid at Mantralaya
# Goat rearing, a highly remunerative venture
# MNREGA funds for rejuvenating Vedavati
# Agumbe ghat road shut for repairs from Dec 20
# Flying squads stir, act against water thefts
# KAU’s zonal advisory council meeting today
# Drought brings down rabi crop area by 40% in 2018-19
# Non_agri_slow
# (0, '0.051*"the" + 0.041*"and" + 0.033*"of" + 0.030*"in" + 0.022*"to" + 0.011*"a" + 0.010*"water" + 0.010*"for" + 0.009*"is" + 0.009*"on"')
# (1, '0.026*"the" + 0.013*"of" + 0.011*"to" + 0.010*"a" + 0.008*"in" + 0.008*"and" + 0.006*"on" + 0.004*"from" + 0.004*"by" + 0.003*"for"')
# (2, '0.037*"the" + 0.030*"of" + 0.024*"and" + 0.019*"in" + 0.012*"to" + 0.012*"a" + 0.011*"for" + 0.007*"on" + 0.006*"is" + 0.005*"at"')
# (3, '0.067*"the" + 0.031*"of" + 0.022*"to" + 0.017*"and" + 0.015*"for" + 0.013*"in" + 0.012*"a" + 0.009*"be" + 0.008*"is" + 0.007*"land"')
# (4, '0.064*"the" + 0.027*"of" + 0.026*"to" + 0.016*"and" + 0.016*"in" + 0.011*"a" + 0.010*"for" + 0.007*"was" + 0.007*"is" + 0.007*"on"')
# (5, '0.018*"and" + 0.015*"the" + 0.009*"in" + 0.009*"of" + 0.007*"to" + 0.005*"a" + 0.004*"at" + 0.003*"for" + 0.003*"will" + 0.002*"on"')
# (6, '0.012*"the" + 0.008*"of" + 0.008*"in" + 0.008*"and" + 0.007*"to" + 0.004*"for" + 0.003*"a" + 0.003*"is" + 0.002*"that" + 0.002*"on"')
# (7, '0.068*"the" + 0.033*"of" + 0.031*"in" + 0.029*"to" + 0.026*"and" + 0.019*"a" + 0.011*"on" + 0.010*"for" + 0.009*"is" + 0.008*"that"')
# (8, '0.058*"the" + 0.038*"of" + 0.024*"and" + 0.024*"to" + 0.020*"in" + 0.015*"for" + 0.014*"a" + 0.008*"at" + 0.007*"is" + 0.007*"that"')
# (9, '0.042*"the" + 0.019*"of" + 0.016*"to" + 0.014*"and" + 0.013*"in" + 0.008*"a" + 0.005*"on" + 0.005*"for" + 0.004*"from" + 0.004*"is"')
# 259
# Rain lashes district, dam shutters opened
# 1 lakh saplings will be planted along Hindon, says DM
# Land for rehabilitation centre identified
# Karnataka SSLC exam results: Manjunath worked in the fields, yet scored 96.6%
# 'Tough deliveries' from J&amp;K keep bat makers on tenterhooks
# Storage boost for lifeline dam
# Central scheme to support farm ventures of women
# Inflated onion rates reined in
# Works being carried out in government schools
# Coastal cops hit by dearth of fuel stations
# Non_agri_stag
# (0, '0.035*"the" + 0.028*"in" + 0.025*"and" + 0.024*"of" + 0.013*"to" + 0.010*"degrees" + 0.008*"a" + 0.008*"at" + 0.008*"was" + 0.006*"is"')
# (1, '0.066*"the" + 0.030*"of" + 0.029*"in" + 0.028*"to" + 0.024*"and" + 0.020*"a" + 0.011*"is" + 0.010*"that" + 0.010*"on" + 0.009*"for"')
# (2, '0.037*"and" + 0.012*"in" + 0.012*"the" + 0.011*"0" + 0.010*"of" + 0.007*"each," + 0.007*"at" + 0.006*"over" + 0.006*"25" + 0.005*"to"')
# (3, '0.014*"the" + 0.012*"and" + 0.009*"of" + 0.008*"to" + 0.006*"in" + 0.005*"a" + 0.004*"for" + 0.003*"is" + 0.003*"on" + 0.002*"has"')
# (4, '0.031*"and" + 0.030*"the" + 0.028*"of" + 0.021*"in" + 0.019*"to" + 0.014*"a" + 0.010*"for" + 0.008*"is" + 0.007*"on" + 0.007*"Rs"')
# (5, '0.062*"the" + 0.035*"of" + 0.022*"and" + 0.018*"to" + 0.015*"a" + 0.011*"in" + 0.009*"is" + 0.008*"on" + 0.007*"for" + 0.007*"that"')
# (6, '0.061*"the" + 0.031*"and" + 0.029*"to" + 0.029*"of" + 0.027*"in" + 0.020*"a" + 0.011*"on" + 0.010*"for" + 0.008*"at" + 0.007*"The"')
# (7, '0.038*"the" + 0.020*"in" + 0.020*"of" + 0.016*"and" + 0.013*"to" + 0.008*"is" + 0.007*"a" + 0.007*"for" + 0.007*"The" + 0.006*"on"')
# (8, '0.062*"the" + 0.044*"of" + 0.030*"to" + 0.029*"and" + 0.021*"in" + 0.016*"for" + 0.011*"a" + 0.009*"is" + 0.009*"on" + 0.008*"has"')
# (9, '0.028*"the" + 0.016*"to" + 0.016*"of" + 0.011*"and" + 0.009*"a" + 0.008*"in" + 0.006*"for" + 0.006*"on" + 0.004*"is" + 0.004*"was"')
# 264
# NGT&thinsp;seeks reply from Haryana govt over 'encroachment' of natural drain in&thinsp;Gurga...
# Cabinet gives nod to revival of state pharmaceutical unit
# Breaking stereotypes to bag King George's Medical University merit, medals
# Mulayam now reaches out to Pawar
# River linking: State accused of criminal negligence
# Sunanda case
# Cabinet frames plot rules
# Valentine's Day: Say it with a red carnation
# Exclusive Interview | After Rajiv, Modi was first PM to get a blank cheque... he blew it: Rahul Gandhi
# The state of the stateless
# Non_agri_fast
# (0, '0.001*"the" + 0.000*"and" + 0.000*"of" + 0.000*"to" + 0.000*"in" + 0.000*"a" + 0.000*"on" + 0.000*"for" + 0.000*"is" + 0.000*"mm"')
# (1, '0.043*"the" + 0.026*"to" + 0.026*"Rs" + 0.026*"of" + 0.023*"in" + 0.018*"a" + 0.015*"and" + 0.013*"prices" + 0.012*"per" + 0.012*"at"')
# (2, '0.074*"the" + 0.035*"of" + 0.034*"to" + 0.026*"and" + 0.023*"in" + 0.021*"a" + 0.011*"is" + 0.011*"for" + 0.010*"that" + 0.010*"on"')
# (3, '0.000*"the" + 0.000*"and" + 0.000*"to" + 0.000*"of" + 0.000*"in" + 0.000*"a" + 0.000*"for" + 0.000*"is" + 0.000*"on" + 0.000*"have"')
# (4, '0.007*"taluk" + 0.007*"Kannada" + 0.006*"Kodagu" + 0.005*"Dakshina" + 0.004*"Bangalore" + 0.004*"Uttara" + 0.003*"Udupi" + 0.003*"Karnataka" + 0.003*"hobli" + 0.003*"Kannada,"')
# (5, '0.033*"and" + 0.018*"of" + 0.014*"the" + 0.011*"in" + 0.008*"students" + 0.007*"at" + 0.007*"a" + 0.006*"to" + 0.006*"0" + 0.005*"on"')
# (6, '0.063*"the" + 0.033*"of" + 0.032*"in" + 0.027*"and" + 0.018*"to" + 0.013*"a" + 0.010*"monsoon" + 0.010*"is" + 0.009*"rainfall" + 0.009*"on"')
# (7, '0.000*"the" + 0.000*"in" + 0.000*"of" + 0.000*"to" + 0.000*"and" + 0.000*"is" + 0.000*"a" + 0.000*"will" + 0.000*"for" + 0.000*"on"')
# (8, '0.059*"the" + 0.040*"of" + 0.032*"and" + 0.030*"in" + 0.029*"to" + 0.015*"for" + 0.014*"a" + 0.011*"is" + 0.009*"on" + 0.008*"that"')
# (9, '0.070*"the" + 0.025*"to" + 0.022*"of" + 0.020*"and" + 0.019*"in" + 0.016*"a" + 0.014*"on" + 0.011*"that" + 0.010*"was" + 0.008*"his"')
# 210
# CM promotes cow-based spiritual farming
# Praja Ballot picks holes in Navya Andhra Pradesh dream
# Suicide in Delhi ups Telangana heat on Congress
# Farmers to picket Mangalore port against WTO conference
# Congress using CBI to extract SP support for food security bill: BJP
# Raj declares drought in 5 dists; Kar in 142 talukas: Pawar
# Pothole website receives nearly 10k complaints since June
# New KAU general council members
# Cuttack gears up to tackle dengue
# AAP tries to lure youth, promises 50,000 new jobs in five years
#
# Collection: Development
# Unemp_slow
# (0, '0.035*"the" + 0.022*"of" + 0.020*"to" + 0.016*"and" + 0.011*"in" + 0.006*"is" + 0.006*"a" + 0.005*"for" + 0.005*"was" + 0.005*"has"')
# (1, '0.042*"the" + 0.024*"to" + 0.022*"of" + 0.018*"in" + 0.016*"and" + 0.014*"a" + 0.009*"for" + 0.008*"that" + 0.006*"has" + 0.006*"said"')
# (2, '0.072*"the" + 0.034*"of" + 0.029*"and" + 0.028*"to" + 0.022*"in" + 0.012*"a" + 0.012*"for" + 0.008*"on" + 0.006*"that" + 0.006*"be"')
# (3, '0.047*"the" + 0.024*"of" + 0.018*"and" + 0.017*"to" + 0.012*"in" + 0.010*"for" + 0.009*"a" + 0.007*"on" + 0.006*"has" + 0.005*"with"')
# (4, '0.038*"of" + 0.037*"the" + 0.031*"to" + 0.023*"in" + 0.022*"and" + 0.015*"for" + 0.014*"a" + 0.009*"is" + 0.007*"on" + 0.006*"was"')
# (5, '0.056*"the" + 0.031*"and" + 0.030*"in" + 0.029*"of" + 0.018*"a" + 0.016*"to" + 0.009*"for" + 0.008*"is" + 0.008*"that" + 0.006*"on"')
# (6, '0.051*"the" + 0.030*"to" + 0.028*"in" + 0.021*"of" + 0.021*"and" + 0.015*"a" + 0.011*"on" + 0.009*"for" + 0.008*"is" + 0.006*"has"')
# (7, '0.045*"the" + 0.035*"of" + 0.021*"to" + 0.021*"in" + 0.018*"and" + 0.015*"a" + 0.012*"for" + 0.008*"is" + 0.008*"on" + 0.007*"has"')
# (8, '0.061*"the" + 0.024*"of" + 0.020*"to" + 0.016*"in" + 0.014*"and" + 0.010*"for" + 0.010*"a" + 0.010*"on" + 0.008*"is" + 0.008*"that"')
# (9, '0.040*"the" + 0.030*"of" + 0.019*"in" + 0.019*"to" + 0.013*"and" + 0.009*"is" + 0.008*"a" + 0.008*"for" + 0.006*"from" + 0.006*"on"')
# 224
# Marhoura loco unit may go on stream in 3 yrs
# Mysuru-Kochi flights likely to begin after poll code is lifted
# Nitish Kumar opens stadium, museum in Munger
# Ekma gears up for CM Nitish Kumar’s visit this month
# Shuttle flies outdoors: Badminton’s new version hopes to bring in casual fans, players into fold
# 4,000 junior engineers to be recruited soon: CM Nitish Kumar
# New system to aid wage-earners
# Applicants for MGNREGS work on the rise in cyclone-hit districts
# College dog show
# Jawan suicide
# Unemp_stag
# (0, '0.037*"the" + 0.022*"and" + 0.022*"of" + 0.018*"in" + 0.017*"to" + 0.014*"a" + 0.008*"for" + 0.007*"be" + 0.007*"on" + 0.007*"is"')
# (1, '0.063*"the" + 0.033*"of" + 0.025*"to" + 0.019*"in" + 0.018*"and" + 0.016*"a" + 0.013*"for" + 0.008*"on" + 0.007*"by" + 0.007*"is"')
# (2, '0.041*"the" + 0.025*"of" + 0.023*"in" + 0.021*"and" + 0.019*"to" + 0.016*"a" + 0.009*"for" + 0.009*"that" + 0.008*"is" + 0.007*"has"')
# (3, '0.025*"the" + 0.018*"of" + 0.015*"to" + 0.013*"in" + 0.011*"and" + 0.010*"a" + 0.009*"for" + 0.006*"is" + 0.005*"that" + 0.005*"on"')
# (4, '0.064*"the" + 0.034*"to" + 0.027*"of" + 0.021*"in" + 0.019*"and" + 0.015*"a" + 0.010*"on" + 0.010*"for" + 0.009*"is" + 0.008*"that"')
# (5, '0.050*"the" + 0.028*"of" + 0.026*"to" + 0.026*"in" + 0.024*"and" + 0.014*"for" + 0.010*"on" + 0.009*"a" + 0.007*"is" + 0.006*"at"')
# (6, '0.058*"the" + 0.027*"of" + 0.019*"and" + 0.017*"to" + 0.014*"in" + 0.009*"a" + 0.008*"for" + 0.008*"that" + 0.007*"on" + 0.007*"be"')
# (7, '0.038*"the" + 0.034*"of" + 0.028*"and" + 0.022*"in" + 0.019*"to" + 0.011*"a" + 0.010*"on" + 0.009*"for" + 0.007*"is" + 0.006*"has"')
# (8, '0.019*"of" + 0.016*"the" + 0.010*"to" + 0.009*"in" + 0.009*"on" + 0.007*"a" + 0.007*"and" + 0.005*"The" + 0.005*"for" + 0.003*"from"')
# (9, '0.062*"the" + 0.036*"of" + 0.031*"and" + 0.027*"in" + 0.019*"to" + 0.017*"a" + 0.011*"for" + 0.011*"on" + 0.009*"is" + 0.007*"will"')
# 235
# ‘Centre to boost regional air connectivity in state’
# Coffee plantations: A boon to tribal people
# Sliding down the mountain
# ID cards for street vendors
# Mission UP polls: PM Narendra Modi readies vikas card, asks ministers to focus on short-term projects
# NGOs vie for World Bank aid
# 10,000 toilets built in 10 days in Chhattisgarh
# Riada plans afoot for 2 new units
# Air Journey between Allahabad-Lucknow for Just Rs 967
# DG of Police to monitor rescue operations for release of four employees of rural development department
# Unemp_fast
# (0, '0.057*"the" + 0.035*"of" + 0.024*"to" + 0.020*"a" + 0.015*"in" + 0.015*"and" + 0.010*"for" + 0.010*"is" + 0.009*"that" + 0.007*"on"')
# (1, '0.052*"the" + 0.036*"of" + 0.030*"and" + 0.026*"in" + 0.019*"to" + 0.012*"a" + 0.011*"for" + 0.009*"on" + 0.008*"is" + 0.007*"by"')
# (2, '0.046*"the" + 0.022*"in" + 0.019*"of" + 0.016*"to" + 0.016*"and" + 0.013*"a" + 0.011*"is" + 0.007*"on" + 0.007*"for" + 0.006*"by"')
# (3, '0.040*"the" + 0.026*"of" + 0.014*"to" + 0.012*"in" + 0.010*"and" + 0.008*"a" + 0.008*"is" + 0.006*"on" + 0.005*"for" + 0.005*"are"')
# (4, '0.059*"the" + 0.030*"to" + 0.026*"in" + 0.024*"of" + 0.018*"and" + 0.013*"a" + 0.011*"for" + 0.008*"is" + 0.007*"on" + 0.007*"will"')
# (5, '0.029*"the" + 0.014*"of" + 0.012*"and" + 0.011*"in" + 0.011*"a" + 0.009*"is" + 0.009*"to" + 0.006*"has" + 0.006*"for" + 0.005*"have"')
# (6, '0.037*"the" + 0.017*"of" + 0.011*"to" + 0.010*"a" + 0.010*"and" + 0.010*"in" + 0.008*"for" + 0.006*"is" + 0.005*"on" + 0.005*"The"')
# (7, '0.059*"the" + 0.036*"of" + 0.033*"and" + 0.021*"in" + 0.017*"to" + 0.014*"a" + 0.012*"for" + 0.008*"is" + 0.007*"at" + 0.007*"has"')
# (8, '0.045*"the" + 0.034*"to" + 0.031*"of" + 0.028*"and" + 0.020*"in" + 0.014*"a" + 0.012*"for" + 0.009*"on" + 0.009*"is" + 0.006*"that"')
# (9, '0.058*"the" + 0.023*"and" + 0.020*"in" + 0.019*"to" + 0.018*"of" + 0.013*"a" + 0.010*"is" + 0.009*"for" + 0.009*"on" + 0.008*"will"')
# 195
# MSU to ink six MoUs at Vibrant summit
# Youngsters promote agri-business online
# Pranab praises Odisha culture
# Transplantation on 15,933 ha. over
# Mamata: We provided 33 days of work under MGNREGS
# AN-32 may be taken off critical operations
# Two more DMDK MLAs meet Jayalalithaa
# Cuttack first in disability welfare
# Mass marriage proclamation rally
# NREGS scam: Bhuj taluka development officer arrested
# Agri_slow
# (0, '0.063*"the" + 0.030*"to" + 0.029*"of" + 0.027*"and" + 0.020*"in" + 0.015*"a" + 0.010*"for" + 0.008*"is" + 0.008*"on" + 0.007*"from"')
# (1, '0.053*"the" + 0.029*"of" + 0.028*"to" + 0.023*"and" + 0.015*"in" + 0.008*"a" + 0.007*"that" + 0.006*"for" + 0.006*"is" + 0.006*"at"')
# (2, '0.058*"the" + 0.027*"of" + 0.025*"to" + 0.020*"and" + 0.018*"a" + 0.018*"in" + 0.013*"for" + 0.008*"that" + 0.008*"on" + 0.006*"is"')
# (3, '0.065*"the" + 0.030*"in" + 0.024*"of" + 0.021*"to" + 0.018*"and" + 0.012*"a" + 0.010*"for" + 0.008*"be" + 0.007*"is" + 0.006*"that"')
# (4, '0.043*"the" + 0.041*"of" + 0.032*"in" + 0.025*"to" + 0.019*"and" + 0.014*"a" + 0.013*"for" + 0.006*"that" + 0.006*"on" + 0.006*"has"')
# (5, '0.060*"the" + 0.023*"in" + 0.022*"to" + 0.021*"and" + 0.021*"of" + 0.010*"a" + 0.008*"for" + 0.008*"on" + 0.007*"is" + 0.006*"are"')
# (6, '0.018*"the" + 0.014*"to" + 0.012*"of" + 0.009*"and" + 0.008*"in" + 0.006*"a" + 0.005*"for" + 0.004*"is" + 0.004*"was" + 0.003*"that"')
# (7, '0.063*"the" + 0.030*"and" + 0.030*"in" + 0.027*"of" + 0.026*"to" + 0.013*"a" + 0.012*"for" + 0.010*"that" + 0.009*"on" + 0.007*"is"')
# (8, '0.059*"the" + 0.039*"of" + 0.027*"to" + 0.025*"and" + 0.019*"in" + 0.011*"for" + 0.010*"a" + 0.010*"on" + 0.007*"that" + 0.006*"at"')
# (9, '0.036*"the" + 0.021*"of" + 0.015*"to" + 0.014*"and" + 0.013*"in" + 0.009*"a" + 0.007*"is" + 0.006*"for" + 0.006*"that" + 0.005*"by"')
# 246
# A model village in the making
# Poverty feeds child migration in Srikakulam
# Withdraw ad on bonded labour: NGO
# Absu meet
# A change for the better in government schools
# KT Rama Rao, K Kavitha to share dais in Armoor
# Change in Manipal Volvo bus timings
# Plan to increase green cover in Namakkal district
# Rahul attacks PM Modi, asks him to practice what he preaches
# Voting against alcohol
# Agri_stag
# (0, '0.026*"the" + 0.018*"and" + 0.013*"in" + 0.012*"of" + 0.010*"to" + 0.008*"a" + 0.008*"for" + 0.007*"on" + 0.006*"be" + 0.005*"that"')
# (1, '0.059*"the" + 0.030*"of" + 0.026*"and" + 0.021*"to" + 0.018*"in" + 0.014*"a" + 0.014*"for" + 0.009*"on" + 0.008*"be" + 0.007*"is"')
# (2, '0.040*"the" + 0.025*"to" + 0.025*"of" + 0.020*"in" + 0.017*"and" + 0.010*"for" + 0.010*"a" + 0.008*"on" + 0.008*"that" + 0.007*"is"')
# (3, '0.082*"the" + 0.028*"of" + 0.025*"to" + 0.018*"in" + 0.015*"and" + 0.012*"for" + 0.011*"a" + 0.007*"The" + 0.007*"on" + 0.006*"is"')
# (4, '0.056*"the" + 0.035*"of" + 0.029*"and" + 0.028*"in" + 0.018*"to" + 0.010*"for" + 0.009*"on" + 0.008*"a" + 0.007*"at" + 0.007*"The"')
# (5, '0.039*"the" + 0.037*"and" + 0.030*"to" + 0.029*"of" + 0.022*"in" + 0.013*"a" + 0.012*"for" + 0.009*"is" + 0.008*"on" + 0.008*"be"')
# (6, '0.028*"the" + 0.018*"to" + 0.014*"in" + 0.014*"of" + 0.012*"and" + 0.010*"a" + 0.008*"is" + 0.007*"for" + 0.006*"from" + 0.005*"on"')
# (7, '0.061*"the" + 0.030*"of" + 0.028*"in" + 0.026*"and" + 0.025*"to" + 0.019*"a" + 0.009*"for" + 0.007*"on" + 0.007*"is" + 0.007*"from"')
# (8, '0.054*"the" + 0.028*"of" + 0.021*"to" + 0.020*"in" + 0.013*"and" + 0.010*"for" + 0.008*"is" + 0.008*"a" + 0.007*"at" + 0.006*"that"')
# (9, '0.044*"the" + 0.036*"of" + 0.022*"in" + 0.021*"and" + 0.021*"to" + 0.013*"a" + 0.011*"for" + 0.007*"is" + 0.007*"on" + 0.006*"will"')
# 227
# Divided borough: Telangana MLA wants say in AP house too
# Sachin bats for Nellore village development
# Maoists torch four vehicles in Odisha
# 1 held in wheat dumping case
# Andhra Pradesh CM N Chandrababu Naidu  asks collectors to meet farm ponds targets by March end
# Araria civic body move to prevent misuse of power
# N Chandrababu Naidu calls for infrastructure development in villages
# Business skills development programme organised at Vignan University ends
# Stone laid for waterfront project at Bhavanipuram
# The first to get linked with Aadhaar
# Agri_fast
# (0, '0.026*"the" + 0.023*"of" + 0.020*"to" + 0.020*"and" + 0.015*"in" + 0.012*"is" + 0.010*"for" + 0.009*"a" + 0.007*"on" + 0.005*"have"')
# (1, '0.050*"the" + 0.035*"to" + 0.031*"of" + 0.021*"and" + 0.015*"in" + 0.011*"for" + 0.011*"a" + 0.009*"that" + 0.008*"on" + 0.008*"is"')
# (2, '0.057*"the" + 0.028*"of" + 0.022*"in" + 0.021*"to" + 0.019*"and" + 0.014*"a" + 0.011*"for" + 0.010*"that" + 0.008*"is" + 0.007*"are"')
# (3, '0.020*"the" + 0.018*"in" + 0.018*"and" + 0.016*"to" + 0.015*"of" + 0.011*"for" + 0.009*"a" + 0.006*"on" + 0.006*"is" + 0.005*"be"')
# (4, '0.041*"the" + 0.031*"of" + 0.027*"to" + 0.022*"and" + 0.021*"in" + 0.012*"a" + 0.011*"for" + 0.010*"is" + 0.008*"that" + 0.008*"on"')
# (5, '0.027*"the" + 0.023*"of" + 0.015*"and" + 0.010*"in" + 0.010*"to" + 0.009*"a" + 0.006*"is" + 0.006*"on" + 0.005*"for" + 0.004*"with"')
# (6, '0.027*"the" + 0.024*"and" + 0.023*"in" + 0.023*"of" + 0.021*"to" + 0.012*"a" + 0.009*"is" + 0.008*"for" + 0.007*"are" + 0.006*"on"')
# (7, '0.030*"the" + 0.018*"and" + 0.017*"of" + 0.016*"in" + 0.015*"to" + 0.008*"is" + 0.008*"a" + 0.008*"on" + 0.008*"for" + 0.007*"be"')
# (8, '0.072*"the" + 0.027*"in" + 0.024*"of" + 0.021*"and" + 0.020*"to" + 0.015*"a" + 0.012*"for" + 0.009*"is" + 0.007*"will" + 0.007*"on"')
# (9, '0.070*"the" + 0.031*"of" + 0.028*"and" + 0.025*"in" + 0.023*"to" + 0.015*"a" + 0.010*"for" + 0.009*"is" + 0.009*"on" + 0.007*"that"')
# 170
# New Solapur-Bangalore train in rail budget likely
# MNREGA funds to revive two more rivers
# Imported buoys to be floated in Gulf of Mannar
# BJP bests Congress, JD-S in Karnataka district polls
# Tribal areas undergoing socio-economic transformation in Himachal: Study
# Dual taxation puts off Koreans
# Maharashtra to sign MoU for development of 10 airports in the state
# Parched earth, broken promises
# Falling potato prices worries Idukki farmers
# Pay revision for polytechnic teachers okayed
# Non_agri_slow
# (0, '0.066*"the" + 0.035*"of" + 0.030*"to" + 0.022*"and" + 0.020*"in" + 0.011*"for" + 0.010*"a" + 0.008*"at" + 0.008*"is" + 0.007*"on"')
# (1, '0.030*"the" + 0.023*"of" + 0.019*"and" + 0.018*"in" + 0.013*"a" + 0.012*"to" + 0.010*"on" + 0.008*"for" + 0.007*"that" + 0.006*"be"')
# (2, '0.013*"the" + 0.012*"to" + 0.012*"of" + 0.006*"and" + 0.005*"a" + 0.005*"pm:" + 0.005*"in" + 0.004*"on" + 0.004*"for" + 0.004*"at"')
# (3, '0.036*"the" + 0.024*"to" + 0.021*"and" + 0.016*"of" + 0.015*"in" + 0.011*"a" + 0.010*"for" + 0.010*"is" + 0.005*"at" + 0.005*"said"')
# (4, '0.043*"the" + 0.028*"of" + 0.025*"to" + 0.023*"in" + 0.016*"and" + 0.011*"a" + 0.010*"for" + 0.009*"on" + 0.007*"was" + 0.006*"that"')
# (5, '0.039*"the" + 0.024*"and" + 0.024*"of" + 0.022*"in" + 0.019*"to" + 0.014*"for" + 0.011*"a" + 0.008*"on" + 0.006*"at" + 0.005*"was"')
# (6, '0.037*"the" + 0.022*"and" + 0.017*"to" + 0.016*"in" + 0.013*"of" + 0.008*"for" + 0.008*"a" + 0.006*"on" + 0.006*"will" + 0.005*"be"')
# (7, '0.056*"the" + 0.029*"to" + 0.024*"of" + 0.020*"in" + 0.020*"and" + 0.017*"a" + 0.010*"on" + 0.008*"for" + 0.007*"pm:" + 0.007*"at"')
# (8, '0.043*"the" + 0.025*"and" + 0.024*"of" + 0.021*"in" + 0.020*"to" + 0.010*"for" + 0.010*"a" + 0.009*"on" + 0.008*"at" + 0.007*"is"')
# (9, '0.045*"the" + 0.028*"of" + 0.026*"and" + 0.021*"in" + 0.019*"to" + 0.013*"a" + 0.008*"for" + 0.006*"on" + 0.006*"at" + 0.006*"be"')
# 221
# Kozhikode Engagement
# Digital India's success is still far away, says ZP&#8200;CEO&#8200;Ravi
# Farmers exposed to water saving techniques
# 650 houses in Perabe have solar lights now
# Variety programmes, competitions mark Yercaud flower festival
# Rising demand for plane parking space in Chennai
# Alumni rise to the occasion
# Monsoon expected to enter Udupi district by month-end
# NIT-T reaches out to colleges to promote entrepreneurship
# 92 New Flight Routes In Northeast Under Udaan-2: Jayant Sinha
# Non_agri_stag
# (0, '0.054*"the" + 0.030*"of" + 0.026*"and" + 0.022*"in" + 0.022*"to" + 0.020*"a" + 0.014*"for" + 0.012*"is" + 0.009*"that" + 0.009*"will"')
# (1, '0.049*"the" + 0.021*"in" + 0.021*"of" + 0.015*"to" + 0.015*"and" + 0.015*"a" + 0.012*"is" + 0.011*"for" + 0.009*"that" + 0.006*"was"')
# (2, '0.046*"the" + 0.025*"of" + 0.023*"to" + 0.015*"in" + 0.014*"for" + 0.009*"and" + 0.009*"a" + 0.009*"is" + 0.006*"by" + 0.005*"from"')
# (3, '0.056*"the" + 0.025*"to" + 0.018*"in" + 0.015*"and" + 0.014*"of" + 0.014*"a" + 0.013*"for" + 0.007*"will" + 0.007*"that" + 0.007*"be"')
# (4, '0.039*"the" + 0.029*"to" + 0.020*"in" + 0.019*"of" + 0.015*"and" + 0.015*"a" + 0.013*"is" + 0.009*"on" + 0.009*"for" + 0.007*"that"')
# (5, '0.066*"the" + 0.036*"of" + 0.027*"to" + 0.027*"and" + 0.024*"in" + 0.012*"a" + 0.011*"for" + 0.009*"on" + 0.008*"that" + 0.007*"has"')
# (6, '0.059*"the" + 0.035*"of" + 0.027*"and" + 0.026*"to" + 0.018*"in" + 0.016*"a" + 0.009*"on" + 0.009*"is" + 0.009*"for" + 0.007*"has"')
# (7, '0.034*"the" + 0.023*"to" + 0.017*"and" + 0.017*"in" + 0.016*"of" + 0.014*"a" + 0.009*"for" + 0.008*"on" + 0.007*"is" + 0.005*"was"')
# (8, '0.030*"the" + 0.024*"of" + 0.020*"and" + 0.020*"to" + 0.016*"in" + 0.011*"for" + 0.009*"a" + 0.006*"is" + 0.006*"that" + 0.006*"on"')
# (9, '0.047*"the" + 0.028*"of" + 0.024*"in" + 0.021*"to" + 0.019*"and" + 0.008*"that" + 0.007*"a" + 0.007*"is" + 0.007*"on" + 0.006*"are"')
# 213
# e-toilets soon in Cherthala
# Consulting firms like EY, Deloitte, Cognizant flocking to IIMs to hire MBA graduates this year
# BPOs no longer calling out to students
# Book online for Surajkund mela
# High-speed facility in 400 railway stations by 2017-end
# Haryana officials take stock of Modi's Faridabad visit
# Airports Authority of India hails UDAN scheme for exponential growth
# Malfunctioning EVMs  missing voter names in Lucknow municipal polls
# UP tops in central rural housing scheme for poor
# Centre asks NGT to commission another air pollution study before deciding on diesel ban
# Non_agri_fast
# (0, '0.040*"of" + 0.036*"and" + 0.019*"on" + 0.010*"College" + 0.010*"10" + 0.009*"by" + 0.008*"for" + 0.006*"the" + 0.005*"6.30" + 0.005*"S."')
# (1, '0.013*"the" + 0.009*"and" + 0.008*"of" + 0.007*"to" + 0.004*"in" + 0.004*"on" + 0.003*"will" + 0.003*"a" + 0.003*"be" + 0.003*"for"')
# (2, '0.006*"the" + 0.004*"of" + 0.003*"and" + 0.003*"to" + 0.003*"in" + 0.002*"on" + 0.002*"a" + 0.001*"for" + 0.001*"that" + 0.001*"is"')
# (3, '0.020*"of" + 0.019*"the" + 0.017*"and" + 0.017*"to" + 0.013*"in" + 0.011*"a" + 0.011*"is" + 0.008*"for" + 0.006*"on" + 0.004*"The"')
# (4, '0.006*"the" + 0.005*"and" + 0.003*"of" + 0.003*"to" + 0.003*"in" + 0.002*"for" + 0.002*"a" + 0.001*"on" + 0.001*"was" + 0.001*"will"')
# (5, '0.051*"the" + 0.032*"and" + 0.032*"to" + 0.029*"of" + 0.025*"in" + 0.020*"a" + 0.012*"on" + 0.012*"for" + 0.009*"is" + 0.009*"will"')
# (6, '0.031*"the" + 0.026*"of" + 0.019*"in" + 0.017*"and" + 0.016*"to" + 0.009*"a" + 0.009*"on" + 0.007*"for" + 0.007*"will" + 0.007*"is"')
# (7, '0.070*"the" + 0.034*"of" + 0.030*"to" + 0.028*"and" + 0.025*"in" + 0.018*"a" + 0.013*"for" + 0.011*"is" + 0.009*"that" + 0.009*"on"')
# (8, '0.001*"the" + 0.001*"of" + 0.001*"and" + 0.001*"to" + 0.001*"in" + 0.000*"a" + 0.000*"on" + 0.000*"for" + 0.000*"is" + 0.000*"has"')
# (9, '0.003*"the" + 0.002*"and" + 0.002*"to" + 0.002*"of" + 0.001*"in" + 0.001*"for" + 0.001*"a" + 0.001*"on" + 0.001*"is" + 0.000*"that"')
# 160
# Vizag-Rajamahendravaram IndiGo flight takes off
# Andy in semis
# Government plans to invest Rs 1.45 lakh crore in North-East road infrastructure
# BHEL commissions another 660 MW thermal unit in UP
# Govt relaxes norms for dvpt fund release for J&K, NE states
# Letters to the Editor: Feb. 3
# Maoists nail labourer to a bridge in Balaghat
# ‘New train will boost Bidar’s industry, tourism’
# PM Modi flags off Mahamana Express from Varanasi
# Sporting Lisbon may rope 	in Chettri
#
# Collection: Environment
# Unemp_slow
# (0, '0.035*"the" + 0.020*"of" + 0.016*"in" + 0.013*"and" + 0.010*"a" + 0.009*"to" + 0.005*"for" + 0.005*"is" + 0.005*"on" + 0.004*"from"')
# (1, '0.042*"the" + 0.033*"of" + 0.026*"and" + 0.020*"in" + 0.014*"to" + 0.009*"a" + 0.008*"for" + 0.007*"on" + 0.007*"that" + 0.007*"is"')
# (2, '0.015*"the" + 0.009*"to" + 0.009*"of" + 0.008*"in" + 0.005*"and" + 0.004*"a" + 0.003*"that" + 0.003*"be" + 0.002*"on" + 0.002*"for"')
# (3, '0.028*"the" + 0.020*"of" + 0.012*"and" + 0.010*"in" + 0.007*"a" + 0.007*"to" + 0.005*"on" + 0.004*"is" + 0.004*"said" + 0.004*"for"')
# (4, '0.057*"the" + 0.039*"of" + 0.034*"and" + 0.029*"in" + 0.027*"to" + 0.019*"a" + 0.010*"is" + 0.008*"on" + 0.008*"that" + 0.008*"for"')
# (5, '0.024*"the" + 0.012*"to" + 0.011*"in" + 0.009*"of" + 0.009*"and" + 0.007*"a" + 0.003*"that" + 0.003*"is" + 0.003*"have" + 0.003*"for"')
# (6, '0.082*"the" + 0.035*"of" + 0.026*"and" + 0.025*"to" + 0.024*"in" + 0.014*"a" + 0.012*"for" + 0.012*"on" + 0.009*"that" + 0.008*"is"')
# (7, '0.030*"the" + 0.021*"and" + 0.016*"to" + 0.015*"of" + 0.012*"in" + 0.007*"a" + 0.006*"for" + 0.005*"on" + 0.005*"is" + 0.004*"has"')
# (8, '0.052*"the" + 0.030*"in" + 0.028*"of" + 0.020*"on" + 0.019*"and" + 0.016*"a" + 0.015*"to" + 0.010*"was" + 0.010*"at" + 0.007*"from"')
# (9, '0.068*"the" + 0.029*"of" + 0.029*"to" + 0.028*"in" + 0.023*"and" + 0.021*"a" + 0.014*"on" + 0.011*"for" + 0.010*"was" + 0.010*"from"')
# 184
# Solatium for families of rain victims
# "Colleagues Weren't Bothered," Says Family Of Soldier Who Died Of Thirst
# Fishing cat census must to protect them, say experts
# JeM militant killed in Kashmir encounter
# Tourism leg-up for Tumpreng
# Forest department to launch campaign for conservation of Sarus crane
# ‘At home’ polling booths for Jenu Kurubas
# World Tribal Day 2019: The Movements of Indigenous People in India
# Seven-foot-long crocodile caught from residential area
# 158 endangered turtles rescued in Auraiya
# Unemp_stag
# (0, '0.025*"the" + 0.011*"of" + 0.011*"and" + 0.009*"to" + 0.007*"in" + 0.006*"a" + 0.005*"is" + 0.004*"have" + 0.003*"for" + 0.003*"on"')
# (1, '0.003*"the" + 0.002*"to" + 0.002*"in" + 0.001*"a" + 0.001*"and" + 0.001*"of" + 0.001*"by" + 0.001*"on" + 0.001*"from" + 0.001*"that"')
# (2, '0.063*"the" + 0.030*"in" + 0.028*"and" + 0.026*"of" + 0.022*"a" + 0.021*"to" + 0.012*"on" + 0.009*"was" + 0.008*"for" + 0.008*"from"')
# (3, '0.012*"the" + 0.011*"of" + 0.007*"to" + 0.006*"and" + 0.005*"a" + 0.005*"in" + 0.003*"is" + 0.002*"for" + 0.002*"are" + 0.002*"that"')
# (4, '0.057*"the" + 0.036*"of" + 0.031*"to" + 0.022*"in" + 0.020*"a" + 0.016*"and" + 0.012*"on" + 0.010*"for" + 0.009*"is" + 0.008*"The"')
# (5, '0.069*"the" + 0.038*"of" + 0.033*"and" + 0.028*"to" + 0.025*"in" + 0.015*"a" + 0.012*"for" + 0.010*"on" + 0.010*"is" + 0.007*"that"')
# (6, '0.019*"the" + 0.011*"of" + 0.011*"in" + 0.007*"and" + 0.006*"to" + 0.005*"a" + 0.004*"for" + 0.003*"on" + 0.003*"be" + 0.003*"said"')
# (7, '0.060*"the" + 0.035*"of" + 0.034*"in" + 0.019*"a" + 0.019*"to" + 0.018*"and" + 0.017*"on" + 0.010*"was" + 0.009*"from" + 0.008*"The"')
# (8, '0.046*"the" + 0.024*"of" + 0.017*"to" + 0.015*"in" + 0.012*"and" + 0.010*"a" + 0.008*"is" + 0.007*"that" + 0.006*"birds" + 0.005*"from"')
# (9, '0.038*"the" + 0.017*"of" + 0.013*"in" + 0.011*"and" + 0.010*"to" + 0.009*"a" + 0.006*"that" + 0.005*"on" + 0.005*"is" + 0.005*"for"')
# 239
# Dreaded dacoit held in Chitrakoot
# NHAI to consult stakeholders on alignment of coastal highway
# Dead tigress consumed poisonous substance
# Gunmen snatch trader from quarry
# Peafowl abode development project takes off
# Pench Tiger Reserve: At country’s best reserve, lessons in conservation — abundant prey, community outreach
# LPG awaits autorickshaws
# Lioness,leopard found dead in Amreli
# 2 out of 5 sewage treatment plantss start functioning in Poghat, Naini
# Mission  to expand green cover
# Unemp_fast
# (0, '0.040*"the" + 0.032*"of" + 0.019*"in" + 0.015*"to" + 0.013*"and" + 0.008*"on" + 0.008*"a" + 0.006*"that" + 0.005*"The" + 0.005*"for"')
# (1, '0.017*"the" + 0.013*"to" + 0.010*"of" + 0.008*"and" + 0.007*"in" + 0.007*"a" + 0.005*"is" + 0.005*"for" + 0.004*"that" + 0.004*"The"')
# (2, '0.038*"the" + 0.035*"of" + 0.023*"in" + 0.019*"and" + 0.015*"to" + 0.009*"for" + 0.009*"a" + 0.008*"is" + 0.006*"from" + 0.006*"was"')
# (3, '0.036*"the" + 0.024*"and" + 0.020*"of" + 0.019*"in" + 0.017*"to" + 0.012*"a" + 0.007*"was" + 0.006*"on" + 0.006*"for" + 0.006*"are"')
# (4, '0.011*"the" + 0.010*"of" + 0.006*"to" + 0.006*"and" + 0.006*"in" + 0.003*"a" + 0.003*"for" + 0.003*"is" + 0.002*"that" + 0.002*"with"')
# (5, '0.072*"the" + 0.035*"of" + 0.030*"to" + 0.027*"and" + 0.025*"in" + 0.018*"a" + 0.011*"on" + 0.010*"for" + 0.009*"is" + 0.009*"that"')
# (6, '0.037*"the" + 0.025*"of" + 0.019*"in" + 0.016*"to" + 0.014*"a" + 0.014*"and" + 0.008*"for" + 0.008*"was" + 0.007*"on" + 0.005*"that"')
# (7, '0.049*"the" + 0.026*"to" + 0.022*"and" + 0.022*"of" + 0.014*"in" + 0.011*"a" + 0.008*"on" + 0.007*"was" + 0.006*"that" + 0.006*"from"')
# (8, '0.054*"the" + 0.036*"of" + 0.035*"in" + 0.030*"and" + 0.021*"to" + 0.014*"a" + 0.012*"is" + 0.011*"for" + 0.009*"on" + 0.008*"from"')
# (9, '0.033*"of" + 0.031*"the" + 0.029*"and" + 0.018*"to" + 0.015*"in" + 0.010*"a" + 0.008*"for" + 0.007*"on" + 0.007*"by" + 0.005*"is"')
# 242
# Meet to stop sale of paan masala in plastic pouches
# Fed up of stench, Nandesari police seeks GPCB help
# NGO volunteers rescue 10-foot long crocodile from Padra canal
# Impact fee as high as building cost!
# Zoo inmates feel the heat, to get coloured curtains
# Pune almost at bottom of clean station list
# Carcass of a metre-long crocodile was recovered in National Chambal Sanctuary
# Trainee jumbo to be state employee
# KMC raises platforms for Holika Dahan
# Odisha Girl Commits Suicide after 'Obscene' Video Goes Viral on Social Media
# Agri_slow
# (0, '0.081*"the" + 0.045*"of" + 0.028*"to" + 0.026*"in" + 0.023*"and" + 0.018*"a" + 0.011*"for" + 0.010*"that" + 0.009*"on" + 0.009*"is"')
# (1, '0.014*"the" + 0.007*"and" + 0.006*"to" + 0.005*"a" + 0.005*"of" + 0.003*"in" + 0.002*"on" + 0.002*"that" + 0.002*"from" + 0.002*"is"')
# (2, '0.039*"the" + 0.023*"in" + 0.020*"a" + 0.020*"of" + 0.017*"and" + 0.014*"tiger" + 0.013*"to" + 0.010*"was" + 0.007*"on" + 0.007*"The"')
# (3, '0.051*"the" + 0.026*"of" + 0.024*"and" + 0.023*"in" + 0.020*"a" + 0.017*"on" + 0.015*"to" + 0.015*"was" + 0.008*"from" + 0.008*"forest"')
# (4, '0.069*"the" + 0.030*"of" + 0.025*"and" + 0.022*"in" + 0.018*"to" + 0.018*"a" + 0.012*"on" + 0.011*"police" + 0.011*"were" + 0.009*"from"')
# (5, '0.062*"the" + 0.035*"in" + 0.033*"and" + 0.032*"of" + 0.031*"to" + 0.017*"a" + 0.011*"for" + 0.010*"on" + 0.009*"is" + 0.008*"from"')
# (6, '0.003*"the" + 0.003*"of" + 0.002*"to" + 0.002*"in" + 0.002*"and" + 0.001*"a" + 0.001*"was" + 0.001*"is" + 0.001*"that" + 0.001*"for"')
# (7, '0.035*"the" + 0.029*"and" + 0.024*"in" + 0.021*"to" + 0.021*"of" + 0.018*"a" + 0.013*"was" + 0.010*"on" + 0.010*"at" + 0.009*"were"')
# (8, '0.069*"the" + 0.031*"to" + 0.030*"of" + 0.024*"and" + 0.016*"in" + 0.012*"for" + 0.011*"on" + 0.010*"be" + 0.009*"a" + 0.009*"that"')
# (9, '0.042*"the" + 0.021*"to" + 0.016*"in" + 0.014*"of" + 0.012*"and" + 0.011*"a" + 0.009*"is" + 0.005*"are" + 0.005*"that" + 0.005*"on"')
# 241
# Two forest officials to be tried for illegal mining
# Arrest may drag Kumaraswamy into illegal mining case
# TN's Share from Cauvery Should Be Reduced by 50 Tmcft: Karnataka Minister MB Patil
# Meghalya forest minister lauds NGT ban
# Forest cover lost on 1.8 lakh hectares: Minister
# 'Weed invasion causing man-elephant conflict'
# Minor forest produce slowly vanishing in Agency areas
# TRS’ number is 37 in Adilabad
# ‘Lack of fodder not the reason for jumbo intrusions'
# Maoist scare: Lens on border villages of T'gana
# Agri_stag
# (0, '0.076*"the" + 0.037*"of" + 0.030*"and" + 0.029*"to" + 0.026*"in" + 0.015*"a" + 0.012*"for" + 0.010*"on" + 0.009*"is" + 0.008*"that"')
# (1, '0.057*"the" + 0.033*"of" + 0.033*"in" + 0.027*"to" + 0.025*"and" + 0.023*"a" + 0.012*"on" + 0.010*"was" + 0.009*"from" + 0.008*"for"')
# (2, '0.003*"Rd.," + 0.002*"Nagar," + 0.002*"of" + 0.002*"Church," + 0.001*"School," + 0.001*"7" + 0.001*"Colony," + 0.001*"the" + 0.001*"Mylapore," + 0.001*"Sri"')
# (3, '0.040*"the" + 0.018*"of" + 0.010*"in" + 0.009*"to" + 0.009*"and" + 0.007*"a" + 0.005*"at" + 0.004*"is" + 0.004*"for" + 0.003*"said"')
# (4, '0.016*"the" + 0.011*"of" + 0.006*"in" + 0.006*"to" + 0.005*"and" + 0.004*"a" + 0.003*"was" + 0.003*"for" + 0.002*"is" + 0.002*"has"')
# (5, '0.004*"the" + 0.002*"of" + 0.002*"in" + 0.002*"to" + 0.001*"and" + 0.001*"for" + 0.001*"a" + 0.001*"that" + 0.001*"is" + 0.001*"from"')
# (6, '0.013*"the" + 0.008*"in" + 0.008*"of" + 0.007*"to" + 0.004*"a" + 0.004*"and" + 0.003*"is" + 0.002*"for" + 0.002*"that" + 0.002*"on"')
# (7, '0.008*"the" + 0.005*"to" + 0.004*"and" + 0.004*"of" + 0.003*"in" + 0.003*"a" + 0.002*"on" + 0.002*"is" + 0.001*"at" + 0.001*"be"')
# (8, '0.010*"the" + 0.008*"of" + 0.006*"to" + 0.005*"in" + 0.004*"and" + 0.002*"a" + 0.002*"for" + 0.002*"that" + 0.002*"on" + 0.002*"forest"')
# (9, '0.040*"the" + 0.022*"in" + 0.022*"of" + 0.014*"a" + 0.012*"were" + 0.011*"to" + 0.010*"police" + 0.010*"and" + 0.009*"was" + 0.007*"on"')
# 128
# Three cities of Kerala feature in GIREM'S ‘Future Cities' report
# Tales of a bureaucrat
# Bee boost for honey production in Odisha
# ‘Tribal girl raped, killed and branded Maoist’
# ICG’s Family Day at Sea
# After SC cap on tiger tourism, MP plans to explore new avenues
# SIMI encounter killings haunted Madhya Pradesh CM Chouhan in 2016
# Provide education for our kids, bonded Irula labourers demand
# 9 red sanders smuggling operatives nabbed
# Reservoirs in Tirumala and Chittoor brimming over
# Agri_fast
# (0, '0.056*"the" + 0.033*"and" + 0.024*"of" + 0.024*"in" + 0.020*"to" + 0.011*"a" + 0.011*"for" + 0.008*"on" + 0.008*"The" + 0.007*"is"')
# (1, '0.043*"the" + 0.023*"to" + 0.019*"and" + 0.017*"of" + 0.017*"in" + 0.012*"a" + 0.009*"for" + 0.007*"has" + 0.007*"is" + 0.006*"was"')
# (2, '0.070*"the" + 0.039*"of" + 0.031*"and" + 0.030*"in" + 0.023*"to" + 0.016*"a" + 0.011*"on" + 0.010*"is" + 0.009*"for" + 0.008*"that"')
# (3, '0.026*"the" + 0.011*"of" + 0.008*"and" + 0.008*"to" + 0.008*"in" + 0.005*"for" + 0.004*"on" + 0.003*"a" + 0.003*"is" + 0.003*"have"')
# (4, '0.041*"the" + 0.020*"of" + 0.017*"and" + 0.017*"in" + 0.016*"to" + 0.012*"a" + 0.010*"for" + 0.007*"is" + 0.006*"from" + 0.005*"on"')
# (5, '0.046*"the" + 0.026*"to" + 0.024*"of" + 0.019*"in" + 0.018*"a" + 0.014*"and" + 0.008*"from" + 0.007*"on" + 0.007*"for" + 0.006*"was"')
# (6, '0.044*"the" + 0.034*"of" + 0.027*"to" + 0.018*"and" + 0.014*"in" + 0.013*"a" + 0.012*"is" + 0.010*"for" + 0.007*"that" + 0.006*"have"')
# (7, '0.042*"the" + 0.019*"of" + 0.018*"and" + 0.015*"to" + 0.014*"in" + 0.009*"a" + 0.007*"is" + 0.006*"on" + 0.006*"be" + 0.005*"will"')
# (8, '0.061*"the" + 0.036*"of" + 0.023*"in" + 0.020*"and" + 0.018*"to" + 0.009*"for" + 0.009*"a" + 0.008*"The" + 0.007*"has" + 0.007*"have"')
# (9, '0.058*"the" + 0.035*"to" + 0.027*"of" + 0.026*"in" + 0.021*"and" + 0.020*"a" + 0.012*"for" + 0.010*"was" + 0.009*"on" + 0.009*"that"')
# 224
# Tiger, Tiger Burning Slight
# Four cops suspended in Lohit
# Land grab: Two women, man get one year in jail, Rs 5,000 fine
# Forest officials dismissed over tree felling
# P.C. George seeks CBI probe
# Idukki sanctuary to be a tourist spot soon
# New evergreen tree species found in Western Ghats
# State nod to road project through forest
# Textile processing cluster coming up
# Govt acts tough with tendu contractors
# Non_agri_slow
# (0, '0.007*"the" + 0.005*"and" + 0.004*"of" + 0.004*"to" + 0.003*"in" + 0.002*"a" + 0.001*"for" + 0.001*"on" + 0.001*"is" + 0.001*"The"')
# (1, '0.022*"the" + 0.017*"and" + 0.011*"of" + 0.011*"to" + 0.010*"in" + 0.007*"a" + 0.005*"on" + 0.004*"for" + 0.004*"be" + 0.004*"at"')
# (2, '0.034*"the" + 0.022*"to" + 0.017*"a" + 0.016*"and" + 0.014*"of" + 0.012*"in" + 0.008*"for" + 0.007*"at" + 0.006*"on" + 0.005*"from"')
# (3, '0.070*"the" + 0.031*"to" + 0.030*"of" + 0.027*"and" + 0.026*"in" + 0.021*"a" + 0.012*"on" + 0.010*"was" + 0.008*"that" + 0.008*"is"')
# (4, '0.020*"the" + 0.016*"and" + 0.016*"of" + 0.015*"to" + 0.010*"on" + 0.010*"in" + 0.008*"a" + 0.006*"for" + 0.006*"by" + 0.005*"is"')
# (5, '0.075*"the" + 0.039*"of" + 0.028*"and" + 0.026*"in" + 0.021*"to" + 0.014*"a" + 0.012*"for" + 0.009*"is" + 0.009*"on" + 0.008*"be"')
# (6, '0.045*"the" + 0.032*"of" + 0.029*"to" + 0.028*"and" + 0.027*"in" + 0.016*"a" + 0.012*"for" + 0.012*"on" + 0.010*"is" + 0.008*"from"')
# (7, '0.038*"the" + 0.021*"of" + 0.015*"and" + 0.014*"to" + 0.008*"in" + 0.008*"a" + 0.006*"that" + 0.006*"at" + 0.006*"is" + 0.005*"The"')
# (8, '0.030*"the" + 0.023*"of" + 0.017*"and" + 0.016*"in" + 0.011*"a" + 0.010*"to" + 0.007*"from" + 0.005*"on" + 0.005*"will" + 0.005*"for"')
# (9, '0.026*"the" + 0.024*"and" + 0.020*"to" + 0.018*"of" + 0.013*"in" + 0.009*"a" + 0.006*"on" + 0.006*"for" + 0.005*"will" + 0.004*"is"')
# 250
# Kuldeep freed along border
# Stone-crushing units given six months grace period, says Minister
# Hindus & Muslims faithful extend an 'olive' branch
# Activist ‘surrenders’ before court to highlight pollution of lake
# Cong. for EC action
# Poaching menace continues to haunt Malabar sanctuary
# Government launches index to rank 116 cities on quality of life
# Haryana takes legal cover off 30,000 hectares of foothill land
# Road mishap
# There is no going back
# Non_agri_stag
# (0, '0.054*"the" + 0.026*"of" + 0.020*"to" + 0.017*"and" + 0.013*"in" + 0.009*"for" + 0.009*"on" + 0.007*"a" + 0.006*"be" + 0.006*"will"')
# (1, '0.059*"the" + 0.036*"of" + 0.029*"and" + 0.028*"to" + 0.023*"in" + 0.017*"a" + 0.013*"on" + 0.012*"will" + 0.011*"for" + 0.008*"be"')
# (2, '0.045*"the" + 0.033*"of" + 0.031*"to" + 0.028*"and" + 0.026*"in" + 0.018*"is" + 0.015*"a" + 0.012*"for" + 0.011*"water" + 0.010*"are"')
# (3, '0.048*"the" + 0.031*"of" + 0.030*"to" + 0.025*"and" + 0.025*"in" + 0.015*"a" + 0.011*"is" + 0.010*"on" + 0.008*"that" + 0.008*"for"')
# (4, '0.004*"the" + 0.004*"and" + 0.003*"to" + 0.003*"of" + 0.002*"in" + 0.002*"is" + 0.001*"a" + 0.001*"for" + 0.001*"on" + 0.001*"from"')
# (5, '0.022*"the" + 0.021*"of" + 0.013*"to" + 0.013*"and" + 0.009*"in" + 0.006*"for" + 0.005*"on" + 0.005*"a" + 0.005*"will" + 0.004*"is"')
# ...
# (8, '0.024*"the" + 0.023*"to" + 0.022*"of" + 0.013*"in" + 0.012*"and" + 0.010*"health" + 0.008*"have" + 0.008*"a" + 0.007*"cases" + 0.007*"patients"')
# (9, '0.001*"the" + 0.001*"and" + 0.001*"in" + 0.001*"of" + 0.000*"to" + 0.000*"a" + 0.000*"on" + 0.000*"is" + 0.000*"that" + 0.000*"at"')
# 139
# Legal wrangle over  relic display
# Nagaland CM tables finance bill
# Akhilesh gifts municipal corporation status to Ayodhya-Faizabad
# Aurangzeb, revisited
# Organs of brain-dead man flown from Tiruchi to Chennai
# A Torchbearer of Hope
# CBI forms additional team to probe Unnao rape survivor's car accident
# ‘More centres for newborn screening needed’
# Lalu invites Dream Girl
# Delhi Times: What's Up Campus- Part 5
# Unemp_stag
# (0, '0.000*"the" + 0.000*"and" + 0.000*"of" + 0.000*"to" + 0.000*"in" + 0.000*"a" + 0.000*"for" + 0.000*"is" + 0.000*"said" + 0.000*"that"')
# (1, '0.000*"the" + 0.000*"of" + 0.000*"to" + 0.000*"and" + 0.000*"in" + 0.000*"a" + 0.000*"from" + 0.000*"is" + 0.000*"for" + 0.000*"on"')
# (2, '0.060*"the" + 0.032*"of" + 0.029*"to" + 0.022*"and" + 0.017*"in" + 0.015*"for" + 0.010*"be" + 0.009*"The" + 0.009*"on" + 0.009*"government"')
# (3, '0.065*"the" + 0.034*"of" + 0.028*"in" + 0.026*"to" + 0.026*"and" + 0.022*"a" + 0.015*"on" + 0.014*"was" + 0.010*"police" + 0.009*"had"')
# (4, '0.066*"the" + 0.032*"of" + 0.030*"and" + 0.028*"to" + 0.026*"in" + 0.021*"a" + 0.012*"is" + 0.011*"for" + 0.010*"on" + 0.009*"that"')
# (5, '0.002*"the" + 0.001*"of" + 0.001*"to" + 0.001*"and" + 0.001*"a" + 0.001*"in" + 0.000*"is" + 0.000*"are" + 0.000*"on" + 0.000*"for"')
# (6, '0.045*"the" + 0.036*"of" + 0.030*"and" + 0.026*"to" + 0.021*"in" + 0.010*"is" + 0.010*"are" + 0.009*"a" + 0.008*"for" + 0.008*"have"')
# (7, '0.001*"the" + 0.001*"road" + 0.001*"accidents" + 0.001*"and" + 0.001*"in" + 0.000*"to" + 0.000*"of" + 0.000*"deaths" + 0.000*"a" + 0.000*"fatalities"')
# (8, '0.002*"the" + 0.001*"and" + 0.001*"of" + 0.001*"a" + 0.001*"to" + 0.001*"in" + 0.000*"that" + 0.000*"by" + 0.000*"for" + 0.000*"was"')
# (9, '0.005*"the" + 0.002*"of" + 0.002*"to" + 0.002*"and" + 0.002*"in" + 0.001*"Ltd" + 0.001*"a" + 0.001*"on" + 0.001*"Pvt" + 0.001*"for"')
# 163
# Muzaffarnagar Riots: 4 Years on, Efforts Begin for Compromise
# Students ransack sandbar
# State gets new window to American cultural studies
# Call to action
# Infants die
# Now, Tajganj project to intensify Taj's security
# Sonepur Mela from November 16
# NCR organises health camps for employees
# Cops nab notorious chain-snatcher, seize 6 kg gold
# FIR against violators in Giridih clash
# Unemp_fast
# (0, '0.055*"the" + 0.040*"of" + 0.031*"in" + 0.025*"and" + 0.021*"a" + 0.018*"to" + 0.012*"on" + 0.009*"was" + 0.008*"The" + 0.008*"from"')
# (1, '0.062*"the" + 0.034*"of" + 0.030*"and" + 0.023*"a" + 0.022*"in" + 0.019*"to" + 0.016*"is" + 0.011*"for" + 0.010*"that" + 0.007*"as"')
# (2, '0.012*"the" + 0.006*"and" + 0.005*"of" + 0.005*"in" + 0.005*"a" + 0.004*"to" + 0.002*"for" + 0.002*"is" + 0.002*"that" + 0.002*"was"')
# (3, '0.068*"the" + 0.031*"in" + 0.030*"of" + 0.027*"and" + 0.025*"to" + 0.022*"a" + 0.013*"on" + 0.012*"was" + 0.008*"police" + 0.008*"from"')
# (4, '0.004*"the" + 0.002*"and" + 0.002*"of" + 0.002*"in" + 0.001*"to" + 0.001*"a" + 0.001*"is" + 0.001*"from" + 0.001*"that" + 0.001*"for"')
# (5, '0.010*"the" + 0.006*"and" + 0.005*"in" + 0.004*"a" + 0.004*"of" + 0.004*"to" + 0.002*"was" + 0.002*"that" + 0.002*"on" + 0.002*"for"')
# (6, '0.069*"the" + 0.030*"to" + 0.028*"of" + 0.025*"and" + 0.021*"a" + 0.020*"in" + 0.015*"was" + 0.013*"on" + 0.012*"that" + 0.010*"for"')
# (7, '0.005*"the" + 0.004*"of" + 0.003*"to" + 0.003*"a" + 0.003*"and" + 0.003*"in" + 0.002*"was" + 0.001*"on" + 0.001*"at" + 0.001*"for"')
# (8, '0.056*"the" + 0.038*"of" + 0.032*"and" + 0.031*"to" + 0.029*"in" + 0.016*"a" + 0.011*"for" + 0.011*"is" + 0.008*"are" + 0.008*"on"')
# (9, '0.010*"the" + 0.004*"of" + 0.004*"and" + 0.003*"in" + 0.003*"to" + 0.003*"a" + 0.002*"on" + 0.002*"for" + 0.002*"at" + 0.001*"is"')
# 171
# Minor rioting breaks out in Bawamanpura
# Chandy calls for law to ensure right to health
# MSU to sensitize students on khadi
# Deft caste moves give wings to BJP's 265-plus dream
# UP unveils infrastructure development plan
# Botched operations: National Human Rights commission seeks fresh report
# ‘Regular exercise must for keeping arthritis at bay’
# 'In view of it's religious significance, Allahabad should be renamed Prayag'
# AMC seeks clarity on plastic ban
# Vadodara boy wins tourism painting contest
# Agri_slow
# (0, '0.007*"the" + 0.006*"and" + 0.004*"to" + 0.003*"of" + 0.003*"in" + 0.002*"on" + 0.002*"for" + 0.002*"a" + 0.001*"be" + 0.001*"at"')
# (1, '0.065*"the" + 0.036*"and" + 0.035*"of" + 0.027*"to" + 0.022*"in" + 0.017*"a" + 0.011*"for" + 0.011*"on" + 0.010*"is" + 0.009*"at"')
# (2, '0.019*"the" + 0.010*"of" + 0.009*"in" + 0.008*"to" + 0.006*"and" + 0.006*"a" + 0.004*"for" + 0.003*"is" + 0.002*"on" + 0.002*"with"')
# (3, '0.059*"the" + 0.025*"to" + 0.019*"in" + 0.018*"of" + 0.016*"and" + 0.011*"a" + 0.010*"for" + 0.010*"Minister" + 0.008*"that" + 0.007*"on"')
# (4, '0.029*"the" + 0.017*"to" + 0.014*"of" + 0.010*"a" + 0.009*"and" + 0.008*"in" + 0.008*"on" + 0.005*"was" + 0.005*"were" + 0.004*"buses"')
# (5, '0.070*"the" + 0.032*"of" + 0.030*"in" + 0.026*"and" + 0.019*"to" + 0.019*"a" + 0.012*"for" + 0.010*"from" + 0.009*"on" + 0.009*"is"')
# (6, '0.011*"the" + 0.006*"to" + 0.005*"of" + 0.004*"and" + 0.003*"in" + 0.003*"a" + 0.002*"for" + 0.002*"that" + 0.001*"have" + 0.001*"on"')
# (7, '0.060*"the" + 0.037*"of" + 0.033*"to" + 0.031*"and" + 0.027*"in" + 0.016*"a" + 0.012*"for" + 0.012*"is" + 0.009*"that" + 0.008*"are"')
# (8, '0.023*"the" + 0.016*"and" + 0.015*"of" + 0.012*"in" + 0.012*"to" + 0.005*"for" + 0.005*"on" + 0.005*"a" + 0.004*"at" + 0.004*"from"')
# (9, '0.066*"the" + 0.033*"of" + 0.031*"in" + 0.029*"to" + 0.028*"and" + 0.024*"a" + 0.014*"was" + 0.014*"on" + 0.008*"his" + 0.008*"at"')
# 259
# Two-month-old infant dies six days after rotavirus vaccine
# Struggle built on principles will lead to harmony: Baraguru
# Water from Bharathapuzha poses health hazard in Kerala
# Samitee members in court today
# NGOs draw up safety measures
# 4 ministers join yoga brigade
# Women are safer in Maharashtra than BJP-ruled states: RR Patil
# Health administration move on safe delivery
# Rajan family happy, says he will be safer in Mumbai
# Stress on continuous research
# Agri_stag
# (0, '0.069*"the" + 0.035*"and" + 0.031*"of" + 0.026*"to" + 0.017*"in" + 0.015*"a" + 0.013*"on" + 0.010*"at" + 0.010*"will" + 0.009*"for"')
# (1, '0.065*"the" + 0.032*"of" + 0.029*"to" + 0.029*"in" + 0.028*"and" + 0.026*"a" + 0.012*"on" + 0.012*"was" + 0.009*"that" + 0.009*"for"')
# (2, '0.006*"Natesan" + 0.006*"Rd.," + 0.005*"of" + 0.004*"Nagar," + 0.004*"Church," + 0.003*"and" + 0.003*"on" + 0.003*"7" + 0.003*"School," + 0.002*"the"')
# (3, '0.001*"the" + 0.001*"to" + 0.000*"and" + 0.000*"of" + 0.000*"in" + 0.000*"a" + 0.000*"for" + 0.000*"that" + 0.000*"from" + 0.000*"are"')
# (4, '0.004*"the" + 0.003*"of" + 0.003*"to" + 0.002*"and" + 0.002*"in" + 0.002*"a" + 0.001*"that" + 0.001*"is" + 0.001*"as" + 0.001*"at"')
# (5, '0.053*"the" + 0.033*"of" + 0.032*"and" + 0.031*"to" + 0.029*"in" + 0.016*"is" + 0.015*"a" + 0.012*"are" + 0.011*"for" + 0.008*"have"')
# (6, '0.074*"the" + 0.029*"in" + 0.028*"of" + 0.023*"to" + 0.023*"and" + 0.014*"a" + 0.013*"on" + 0.011*"was" + 0.010*"were" + 0.009*"at"')
# (7, '0.003*"the" + 0.002*"of" + 0.002*"and" + 0.002*"to" + 0.002*"in" + 0.001*"is" + 0.001*"on" + 0.001*"a" + 0.001*"at" + 0.001*"for"')
# (8, '0.029*"the" + 0.013*"to" + 0.013*"of" + 0.012*"and" + 0.011*"in" + 0.009*"for" + 0.006*"on" + 0.005*"Medical" + 0.004*"be" + 0.004*"from"')
# (9, '0.063*"the" + 0.038*"of" + 0.030*"and" + 0.026*"to" + 0.026*"in" + 0.018*"a" + 0.014*"for" + 0.009*"on" + 0.008*"that" + 0.007*"at"')
# 212
# BJP targets Acharya over deal with Seashore
# “We are shown as surrendered Maoists”
# Triple murder: 10-day police custody for three accused
# Chief secretary, DGP attend review meeting in Delhi
# Trekking suspended at Pachamalai
# Kanpur boy tops State Entrance Exam
# ‘Chittoor district poised for growth'
# Strategy for exceptional times
# “Sushmita was vivacious, exuberant and bold”
# Odisha: Swearing of ministry tomorrow, 10 dropped, 11 to be inducted
# Agri_fast
# (0, '0.019*"the" + 0.014*"a" + 0.012*"of" + 0.011*"to" + 0.010*"and" + 0.008*"in" + 0.008*"is" + 0.005*"for" + 0.004*"on" + 0.004*"that"')
# (1, '0.032*"the" + 0.022*"of" + 0.018*"a" + 0.018*"in" + 0.015*"and" + 0.014*"to" + 0.008*"on" + 0.006*"that" + 0.006*"his" + 0.005*"police"')
# (2, '0.040*"the" + 0.033*"and" + 0.031*"of" + 0.022*"in" + 0.019*"a" + 0.019*"to" + 0.015*"on" + 0.012*"for" + 0.009*"at" + 0.008*"will"')
# (3, '0.048*"the" + 0.040*"of" + 0.029*"and" + 0.026*"in" + 0.022*"to" + 0.014*"a" + 0.010*"for" + 0.008*"on" + 0.007*"has" + 0.007*"is"')
# (4, '0.067*"the" + 0.031*"to" + 0.030*"of" + 0.029*"and" + 0.028*"in" + 0.020*"a" + 0.010*"is" + 0.010*"on" + 0.009*"for" + 0.009*"was"')
# (5, '0.009*"the" + 0.006*"of" + 0.005*"to" + 0.004*"and" + 0.004*"in" + 0.003*"a" + 0.002*"on" + 0.002*"for" + 0.002*"that" + 0.001*"are"')
# (6, '0.049*"the" + 0.035*"of" + 0.035*"and" + 0.027*"in" + 0.018*"to" + 0.015*"a" + 0.010*"for" + 0.009*"from" + 0.009*"that" + 0.009*"on"')
# (7, '0.073*"the" + 0.036*"of" + 0.024*"to" + 0.024*"in" + 0.022*"and" + 0.019*"a" + 0.012*"was" + 0.012*"on" + 0.011*"for" + 0.009*"that"')
# (8, '0.052*"the" + 0.024*"to" + 0.021*"of" + 0.020*"a" + 0.017*"and" + 0.013*"in" + 0.009*"that" + 0.009*"was" + 0.008*"on" + 0.006*"for"')
# (9, '0.008*"the" + 0.007*"and" + 0.006*"to" + 0.006*"a" + 0.006*"of" + 0.005*"in" + 0.002*"on" + 0.002*"for" + 0.002*"are" + 0.002*"is"')
# 212
# Odisha government to renovate Bezbaroa house at Sambalpur
# Kalam memorial at Dilli Haat soon
# Intellectual South Indians won’t vote for Modi: Muniyappa
# Hurda party is back, in new avatar
# Students to undergo free health check-up
# Passenger held for transporter's murder
# Escape of undertrial: Needle of suspicion points to police team
# Maharashtra starts 15-day drive to identify new leprosy cases
# Six killed in road accident in Himachal
# Yatnal arrested in Kolhapur
# Non_agri_slow
# (0, '0.045*"the" + 0.032*"and" + 0.028*"a" + 0.028*"in" + 0.026*"of" + 0.025*"to" + 0.013*"on" + 0.012*"was" + 0.009*"his" + 0.009*"from"')
# (1, '0.010*"of" + 0.009*"and" + 0.006*"the" + 0.005*"bt" + 0.004*"on" + 0.003*"to" + 0.003*"overs" + 0.003*"for" + 0.003*"10" + 0.003*"by"')
# (2, '0.069*"the" + 0.034*"of" + 0.031*"and" + 0.029*"to" + 0.025*"in" + 0.018*"a" + 0.012*"for" + 0.011*"is" + 0.010*"on" + 0.008*"be"')
# (3, '0.076*"the" + 0.031*"of" + 0.030*"to" + 0.027*"in" + 0.021*"and" + 0.019*"a" + 0.012*"on" + 0.012*"was" + 0.010*"that" + 0.008*"for"')
# (4, '0.016*"the" + 0.010*"of" + 0.010*"to" + 0.009*"and" + 0.008*"in" + 0.005*"a" + 0.003*"be" + 0.003*"is" + 0.002*"degrees" + 0.002*"at"')
# (5, '0.012*"the" + 0.011*"of" + 0.010*"and" + 0.009*"zoo" + 0.007*"in" + 0.006*"to" + 0.005*"a" + 0.005*"on" + 0.003*"for" + 0.002*"from"')
# (6, '0.057*"the" + 0.033*"of" + 0.031*"in" + 0.029*"and" + 0.022*"to" + 0.012*"on" + 0.010*"a" + 0.010*"for" + 0.010*"at" + 0.008*"was"')
# (7, '0.015*"the" + 0.007*"to" + 0.005*"of" + 0.005*"and" + 0.005*"a" + 0.004*"in" + 0.003*"from" + 0.003*"is" + 0.002*"for" + 0.002*"at"')
# (8, '0.050*"the" + 0.040*"of" + 0.030*"and" + 0.025*"in" + 0.024*"to" + 0.019*"a" + 0.012*"is" + 0.010*"for" + 0.008*"from" + 0.007*"that"')
# (9, '0.008*"the" + 0.004*"of" + 0.003*"and" + 0.003*"to" + 0.003*"a" + 0.003*"at" + 0.002*"in" + 0.002*"on" + 0.002*"was" + 0.001*"for"')
# 248
# Crime bureau ADGP checks progress of online FIR system
# Assam joins chorus for graphic tobacco packs
# Here, guns outnumber roses on  Valentine's Day
# ‘Verdict reinforces boundary between State and judiciary’
# Easy for Mangalore
# Camp focus on govt schemes
# Cotton field child labour employers may face action
# Surfers ride waves for ultimate glory
# Bhagat Singh was ‘bigger’ follower of non-violence than Gandhi, says RSS’s Indresh Kumar
# Health care gets a boost in Vellore
# Non_agri_stag
# (0, '0.051*"the" + 0.046*"of" + 0.041*"and" + 0.026*"in" + 0.019*"to" + 0.012*"a" + 0.010*"for" + 0.010*"on" + 0.008*"at" + 0.008*"is"')
# (1, '0.003*"TB" + 0.000*"the" + 0.000*"of" + 0.000*"to" + 0.000*"in" + 0.000*"and" + 0.000*"a" + 0.000*"for" + 0.000*"is" + 0.000*"from"')
# (2, '0.000*"the" + 0.000*"to" + 0.000*"of" + 0.000*"and" + 0.000*"a" + 0.000*"in" + 0.000*"that" + 0.000*"is" + 0.000*"for" + 0.000*"have"')
# (3, '0.002*"in" + 0.002*"accidents" + 0.002*"the" + 0.001*"of" + 0.001*"per" + 0.001*"cases" + 0.001*"and" + 0.001*"to" + 0.001*"cent" + 0.001*"road"')
# (4, '0.067*"the" + 0.033*"of" + 0.031*"in" + 0.028*"and" + 0.026*"to" + 0.020*"a" + 0.014*"on" + 0.013*"was" + 0.009*"that" + 0.009*"were"')
# (5, '0.050*"the" + 0.030*"a" + 0.030*"to" + 0.028*"and" + 0.028*"of" + 0.024*"in" + 0.017*"is" + 0.011*"that" + 0.010*"I" + 0.010*"with"')
# (6, '0.030*"trains" + 0.024*"train" + 0.018*"passenger" + 0.017*"passengers" + 0.013*"IRCTC" + 0.012*"Railway" + 0.010*"Railways" + 0.009*"Catering" + 0.008*"Rs" + 0.007*"travel"')
# (7, '0.000*"the" + 0.000*"and" + 0.000*"of" + 0.000*"in" + 0.000*"to" + 0.000*"a" + 0.000*"that" + 0.000*"for" + 0.000*"on" + 0.000*"is"')
# (8, '0.004*"Movie" + 0.004*"Nagar," + 0.003*"Garden," + 0.003*"(Raja" + 0.002*"PVR" + 0.002*"Pitampura)," + 0.002*"Noida," + 0.002*"Wave" + 0.002*"Satyam" + 0.002*"Spice"')
# (9, '0.074*"the" + 0.033*"to" + 0.032*"of" + 0.028*"and" + 0.026*"in" + 0.017*"a" + 0.012*"for" + 0.011*"is" + 0.010*"that" + 0.010*"on"')
# 234
# Rain batters Uttar Pradesh, Bihar
# Free path tests at Lohia from today
# Google’s biggest campus outside US in Hyderabad
# Bandit returns to Chambal for film
# Gangs from Iran keep cops on their toes
# 29.74% calls to UP100 related to personal disputes
# Lakshmi Bai’s birthplace to be turned into memorial
# Consequences of deviating from natural farm practices stressed
# Cops arrest 2 persons, claim success in South City case
# Jassie Gill: Maine socha tha Dilli tab jaunga jab logon ko pata hoga Jassie Gill kaun hai
# Non_agri_fast
# (0, '0.002*"AES" + 0.001*"b" + 0.001*"(Marxist)" + 0.001*"the" + 0.001*"c" + 0.000*"IMR" + 0.000*"JE" + 0.000*"to" + 0.000*"of" + 0.000*"innings:"')
# (1, '0.021*"tobacco" + 0.003*"Tobacco" + 0.003*"smoking" + 0.002*"cigarettes" + 0.002*"anti-tobacco" + 0.002*"warnings" + 0.002*"chewing" + 0.001*"tobacco," + 0.001*"ban" + 0.001*"Kirti"')
# (2, '0.055*"the" + 0.038*"of" + 0.034*"and" + 0.031*"to" + 0.022*"in" + 0.019*"a" + 0.014*"is" + 0.012*"for" + 0.009*"are" + 0.009*"that"')
# (3, '0.030*"of" + 0.028*"and" + 0.018*"the" + 0.014*"on" + 0.013*"in" + 0.012*"for" + 0.009*"by" + 0.009*"at" + 0.007*"students" + 0.007*"to"')
# (4, '0.000*"the" + 0.000*"of" + 0.000*"and" + 0.000*"in" + 0.000*"to" + 0.000*"a" + 0.000*"for" + 0.000*"is" + 0.000*"that" + 0.000*"on"')
# (5, '0.001*"the" + 0.001*"and" + 0.001*"Hanif" + 0.001*"a" + 0.000*"to" + 0.000*"of" + 0.000*"in" + 0.000*"DRI" + 0.000*"was" + 0.000*"for"')
# (6, '0.082*"the" + 0.036*"of" + 0.031*"to" + 0.026*"in" + 0.024*"and" + 0.017*"a" + 0.012*"on" + 0.012*"that" + 0.010*"for" + 0.009*"was"')
# (7, '0.054*"the" + 0.030*"and" + 0.028*"to" + 0.027*"of" + 0.027*"a" + 0.025*"in" + 0.014*"is" + 0.011*"for" + 0.009*"with" + 0.009*"that"')
# (8, '0.051*"the" + 0.028*"a" + 0.027*"and" + 0.025*"to" + 0.022*"in" + 0.021*"of" + 0.019*"was" + 0.017*"police" + 0.014*"on" + 0.011*"had"')
# (9, '0.001*"abortion" + 0.001*"the" + 0.001*"to" + 0.001*"of" + 0.001*"abortions" + 0.001*"Pregnancy" + 0.000*"a" + 0.000*"in" + 0.000*"and" + 0.000*"Termination"')
# 245
# Madhya Pradesh losing age-old ‘bana’ rhythm
# Disaster December? See the Five Worst Things to Have Hit Tamil Nadu in the Month
# Blood on streets: Goons thrash nightclub staffer
# Junior docs seek action on principal
# Andhra Pradesh top in crime against women
# Come June, Delhi will have India’s first Madame Tussauds
# Sensex up 20 points after initial losses
# Priority for mental health programme, says official
# Tamil Nadu reviews spread of dengue, seeks public help
# City residents look for welfare oriented Bhopal Municipal Corporation budget
